# %% [markdown]
# # Rearrangement Trap Ramp Down Test

# %%
from pytweezer.experiment.motmaster_client import MotMasterClient
from pytweezer.drivers.imagemX2 import ImagEMX2Camera
from pytweezer.drivers.slm import SLM
from pytweezer.drivers.thorcam import ThorCamera
from pytweezer.experiment.experiment_parameter_manager import ExpParameterManager
import pytweezer.phasemask as pm
import pytweezer.analysis as an
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

ExpParams = ExpParameterManager()

# %%
exp : MotMasterClient = MotMasterClient()
motcam : ThorCamera = ThorCamera(id="motcam")
slm : SLM = SLM()
hamcam : ImagEMX2Camera = ImagEMX2Camera()
# Out:
# Rb MotMasterClient initialised.
# Thorlabs TLCamera - motcam - initialised.
# SLM 1 initialised: 1024x1024 @ 8-bit, serial 7752, 40.230 degC
# SLM 1 loaded LUT "C:\Program Files\Meadowlark Optics\Blink Plus\LUT Files\slm40_at852.LUT"
# ImagEM X2 camera initialised.

# %%
motcam.close()
slm.close()
hamcam.close()
# Out:
# Thorlabs TLCamera - motcam - closed.
# SLM 1 closed.
# ImagEM X2 camera closed.

# %%
exp : MotMasterClient = MotMasterClient()
exp.set_save_toggle(False)
exp.set_run_until_stopped(False)
exp.set_motmaster_experiment("RbTweezerBasic2026_2")

motcam.set_trigger_source("bulb")

hamcam.set_trigger_source("ext")
hamcam.set_external_exposure_mode()
hamcam.enable_em_gain(True)
hamcam.enable_direct_em_gain(True)
hamcam.set_sensitivity(600)
hamcam.timeout = 60*5
X0, Y0, WIDTH, HEIGHT = 110, 220, 256, 256
hamcam.set_roi(X0, WIDTH, Y0, HEIGHT)
# Out:
# Rb MotMasterClient initialised.

# %% [markdown]
# ## Generate Initial and Final Array Hologram

# %%
dx, dy = 8.0, 12.0
PM = pm.OptimisationBasedPhasemaskGeneratorGPU(
                 wavelength_um=0.852,
                 focal_length_mm=17.3,
                 slm_pitch_um=17,
                 slm_res=(1024,1024),
                 input_beam_waist_mm=16,
                 fresnel_f_mm=1072,
                 blaze_dx_dy_um=(40+dx, -8+dy),
                 zernike_coeff_dict={5:1.195, 6:0.725, 7:0.970, 8:0.478, 9:-1.091, 10:0.303, 11:0.021, 12:0.072, 13:0.049})

gauss2d = lambda x, y, A, x0, y0, sx, sy, offset: (A * np.exp(-(((x - x0) ** 2) / (2 * sx ** 2) + ((y - y0) ** 2) / (2 * sy ** 2)))) + offset
A, x0, y0, sx, sy, offset = [-2.14197604e+03, -1.11443850e+01 - dx, 2.09919600e+00 - dy, 2.95002910e+03, 2.64281503e+03, 2.14239505e+03]
# Out:
# --- System Configuration ---
# SLM Plane Width: 17.41 mm
# SLM Plane Height: 17.41 mm
# Focal Plane Resolution x (pixel size): 0.8467 um
# Focal Plane Resolution y (pixel size): 0.8467 um
# Focal Plane Width: 867.04 um
# Focal Plane Height: 867.04 um
# Fresnel Lens Focal Length: 1072.00 mm
# Blazed Grating Displacement (dx, dy): (48.0, 4.0) um

# %% [markdown]
# Initial array

# %%
W1 = np.ones((14,14))
spacing_um = 5.0

w_n, theta_n, x_n1, y_n1 = PM.generate_weighted_array(W1, spacing_um, init_phase_randomness=1.0, angle_deg=2.5)
w_n = gauss2d(x_n1, y_n1, A, x0, y0, sx, sy, offset)

terms1 = [w_n, theta_n, x_n1, y_n1]
pm_array1, terms1, _ = PM.superposition_optimization(terms1, max_iter=2000, damping=0.5, verbose=True)
# Out:
# --- Target Generation ---
# Grid: 14x14
# Spacing: 5.0 um
# --- Starting GPU Superposition Phase Retrieval ---
# Iteration 000 | Mean-Squared Error: 4.68e-06 | Uniformity: 42.84% | Min/Max ratio: 0.037
# Iteration 010 | Mean-Squared Error: 3.99e-08 | Uniformity: 77.04% | Min/Max ratio: 0.399
# Iteration 020 | Mean-Squared Error: 8.37e-09 | Uniformity: 77.31% | Min/Max ratio: 0.393
# Iteration 030 | Mean-Squared Error: 3.80e-09 | Uniformity: 77.48% | Min/Max ratio: 0.408
# Iteration 040 | Mean-Squared Error: 2.15e-09 | Uniformity: 77.57% | Min/Max ratio: 0.406
# Iteration 050 | Mean-Squared Error: 1.76e-09 | Uniformity: 77.56% | Min/Max ratio: 0.412
# Iteration 060 | Mean-Squared Error: 1.19e-09 | Uniformity: 77.40% | Min/Max ratio: 0.411
# Iteration 070 | Mean-Squared Error: 7.58e-10 | Uniformity: 77.37% | Min/Max ratio: 0.409
# Iteration 080 | Mean-Squared Error: 4.59e-10 | Uniformity: 77.35% | Min/Max ratio: 0.409
# Iteration 090 | Mean-Squared Error: 3.07e-10 | Uniformity: 77.37% | Min/Max ratio: 0.407
# Iteration 100 | Mean-Squared Error: 3.17e-10 | Uniformity: 77.41% | Min/Max ratio: 0.408
# Iteration 110 | Mean-Squared Error: 3.03e-10 | Uniformity: 77.44% | Min/Max ratio: 0.409
# Iteration 120 | Mean-Squared Error: 3.60e-10 | Uniformity: 77.48% | Min/Max ratio: 0.410
# Iteration 130 | Mean-Squared Error: 7.50e-10 | Uniformity: 77.52% | Min/Max ratio: 0.411
# Iteration 140 | Mean-Squared Error: 6.98e-10 | Uniformity: 77.48% | Min/Max ratio: 0.408
# Iteration 150 | Mean-Squared Error: 3.14e-10 | Uniformity: 77.42% | Min/Max ratio: 0.407
# Iteration 160 | Mean-Squared Error: 2.10e-10 | Uniformity: 77.41% | Min/Max ratio: 0.407
# Iteration 170 | Mean-Squared Error: 1.44e-10 | Uniformity: 77.42% | Min/Max ratio: 0.407
# Iteration 180 | Mean-Squared Error: 9.84e-11 | Uniformity: 77.44% | Min/Max ratio: 0.408
# Iteration 190 | Mean-Squared Error: 8.61e-11 | Uniformity: 77.46% | Min/Max ratio: 0.409
# Iteration 200 | Mean-Squared Error: 1.10e-10 | Uniformity: 77.47% | Min/Max ratio: 0.409
# Iteration 210 | Mean-Squared Error: 9.69e-11 | Uniformity: 77.48% | Min/Max ratio: 0.409
# Iteration 220 | Mean-Squared Error: 3.65e-11 | Uniformity: 77.47% | Min/Max ratio: 0.409
# Iteration 230 | Mean-Squared Error: 1.61e-11 | Uniformity: 77.47% | Min/Max ratio: 0.410
# Iteration 240 | Mean-Squared Error: 7.74e-12 | Uniformity: 77.46% | Min/Max ratio: 0.410
# Iteration 250 | Mean-Squared Error: 3.81e-12 | Uniformity: 77.46% | Min/Max ratio: 0.410
# Iteration 260 | Mean-Squared Error: 2.09e-12 | Uniformity: 77.46% | Min/Max ratio: 0.410
# Iteration 270 | Mean-Squared Error: 1.04e-12 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 280 | Mean-Squared Error: 5.52e-13 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 290 | Mean-Squared Error: 3.04e-13 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 300 | Mean-Squared Error: 1.86e-13 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 310 | Mean-Squared Error: 1.12e-13 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 320 | Mean-Squared Error: 6.72e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 330 | Mean-Squared Error: 4.37e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 340 | Mean-Squared Error: 3.05e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 350 | Mean-Squared Error: 2.29e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 360 | Mean-Squared Error: 1.86e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 370 | Mean-Squared Error: 1.61e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 380 | Mean-Squared Error: 1.48e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 390 | Mean-Squared Error: 1.39e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 400 | Mean-Squared Error: 1.29e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 410 | Mean-Squared Error: 1.15e-14 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 420 | Mean-Squared Error: 9.95e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 430 | Mean-Squared Error: 8.53e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 440 | Mean-Squared Error: 7.32e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 450 | Mean-Squared Error: 6.36e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 460 | Mean-Squared Error: 5.97e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 470 | Mean-Squared Error: 5.90e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 480 | Mean-Squared Error: 4.92e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 490 | Mean-Squared Error: 4.31e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 500 | Mean-Squared Error: 4.19e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 510 | Mean-Squared Error: 3.90e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 520 | Mean-Squared Error: 3.53e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 530 | Mean-Squared Error: 3.21e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 540 | Mean-Squared Error: 2.93e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 550 | Mean-Squared Error: 2.68e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 560 | Mean-Squared Error: 2.46e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 570 | Mean-Squared Error: 2.25e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 580 | Mean-Squared Error: 2.05e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 590 | Mean-Squared Error: 1.86e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 600 | Mean-Squared Error: 1.68e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 610 | Mean-Squared Error: 1.50e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 620 | Mean-Squared Error: 1.34e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 630 | Mean-Squared Error: 1.18e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 640 | Mean-Squared Error: 1.04e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 650 | Mean-Squared Error: 9.04e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 660 | Mean-Squared Error: 7.80e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 670 | Mean-Squared Error: 6.68e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 680 | Mean-Squared Error: 5.67e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 690 | Mean-Squared Error: 4.77e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 700 | Mean-Squared Error: 3.99e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 710 | Mean-Squared Error: 3.31e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 720 | Mean-Squared Error: 2.73e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 730 | Mean-Squared Error: 2.23e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 740 | Mean-Squared Error: 1.80e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 750 | Mean-Squared Error: 1.44e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 760 | Mean-Squared Error: 1.13e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 770 | Mean-Squared Error: 8.76e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 780 | Mean-Squared Error: 6.66e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 790 | Mean-Squared Error: 5.06e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 800 | Mean-Squared Error: 4.07e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 810 | Mean-Squared Error: 3.87e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 820 | Mean-Squared Error: 4.82e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 830 | Mean-Squared Error: 7.58e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 840 | Mean-Squared Error: 1.27e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 850 | Mean-Squared Error: 1.87e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 860 | Mean-Squared Error: 2.21e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 870 | Mean-Squared Error: 2.17e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 880 | Mean-Squared Error: 1.94e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 890 | Mean-Squared Error: 1.65e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 900 | Mean-Squared Error: 1.39e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 910 | Mean-Squared Error: 1.17e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 920 | Mean-Squared Error: 1.00e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 930 | Mean-Squared Error: 8.67e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 940 | Mean-Squared Error: 7.64e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 950 | Mean-Squared Error: 6.83e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 960 | Mean-Squared Error: 6.16e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 970 | Mean-Squared Error: 5.54e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 980 | Mean-Squared Error: 4.91e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 990 | Mean-Squared Error: 4.33e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1000 | Mean-Squared Error: 3.92e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1010 | Mean-Squared Error: 3.87e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1020 | Mean-Squared Error: 4.38e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1030 | Mean-Squared Error: 5.69e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1040 | Mean-Squared Error: 8.12e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1050 | Mean-Squared Error: 1.19e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1060 | Mean-Squared Error: 1.57e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1070 | Mean-Squared Error: 1.66e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1080 | Mean-Squared Error: 1.50e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1090 | Mean-Squared Error: 1.40e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1100 | Mean-Squared Error: 1.17e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1110 | Mean-Squared Error: 3.90e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1120 | Mean-Squared Error: 3.05e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1130 | Mean-Squared Error: 2.95e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1140 | Mean-Squared Error: 3.12e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1150 | Mean-Squared Error: 3.45e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1160 | Mean-Squared Error: 3.88e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1170 | Mean-Squared Error: 4.40e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1180 | Mean-Squared Error: 5.02e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1190 | Mean-Squared Error: 5.75e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1200 | Mean-Squared Error: 6.70e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1210 | Mean-Squared Error: 8.29e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1220 | Mean-Squared Error: 1.46e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1230 | Mean-Squared Error: 1.91e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1240 | Mean-Squared Error: 1.48e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1250 | Mean-Squared Error: 1.25e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1260 | Mean-Squared Error: 1.16e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1270 | Mean-Squared Error: 1.11e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1280 | Mean-Squared Error: 1.07e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1290 | Mean-Squared Error: 1.03e-15 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1300 | Mean-Squared Error: 9.85e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1310 | Mean-Squared Error: 9.48e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1320 | Mean-Squared Error: 9.20e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1330 | Mean-Squared Error: 9.10e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1340 | Mean-Squared Error: 8.99e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1350 | Mean-Squared Error: 8.33e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1360 | Mean-Squared Error: 7.09e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1370 | Mean-Squared Error: 5.78e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1380 | Mean-Squared Error: 4.74e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1390 | Mean-Squared Error: 4.01e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1400 | Mean-Squared Error: 3.54e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1410 | Mean-Squared Error: 3.27e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1420 | Mean-Squared Error: 3.08e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1430 | Mean-Squared Error: 2.87e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1440 | Mean-Squared Error: 2.69e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1450 | Mean-Squared Error: 2.86e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1460 | Mean-Squared Error: 4.04e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1470 | Mean-Squared Error: 6.32e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1480 | Mean-Squared Error: 5.65e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1490 | Mean-Squared Error: 4.44e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1500 | Mean-Squared Error: 3.80e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1510 | Mean-Squared Error: 3.34e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1520 | Mean-Squared Error: 3.04e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1530 | Mean-Squared Error: 2.84e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1540 | Mean-Squared Error: 2.51e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1550 | Mean-Squared Error: 2.11e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1560 | Mean-Squared Error: 1.79e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1570 | Mean-Squared Error: 1.57e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1580 | Mean-Squared Error: 1.38e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1590 | Mean-Squared Error: 1.22e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1600 | Mean-Squared Error: 1.07e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1610 | Mean-Squared Error: 9.39e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1620 | Mean-Squared Error: 8.31e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1630 | Mean-Squared Error: 7.56e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1640 | Mean-Squared Error: 7.23e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1650 | Mean-Squared Error: 7.30e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1660 | Mean-Squared Error: 7.24e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1670 | Mean-Squared Error: 6.34e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1680 | Mean-Squared Error: 5.06e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1690 | Mean-Squared Error: 4.20e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1700 | Mean-Squared Error: 3.83e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1710 | Mean-Squared Error: 3.84e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1720 | Mean-Squared Error: 4.16e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1730 | Mean-Squared Error: 4.75e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1740 | Mean-Squared Error: 5.54e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1750 | Mean-Squared Error: 6.59e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1760 | Mean-Squared Error: 8.69e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1770 | Mean-Squared Error: 1.50e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1780 | Mean-Squared Error: 3.39e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1790 | Mean-Squared Error: 5.85e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1800 | Mean-Squared Error: 5.51e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1810 | Mean-Squared Error: 3.73e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1820 | Mean-Squared Error: 2.54e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1830 | Mean-Squared Error: 1.98e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1840 | Mean-Squared Error: 1.79e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1850 | Mean-Squared Error: 1.78e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1860 | Mean-Squared Error: 1.86e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1870 | Mean-Squared Error: 1.97e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1880 | Mean-Squared Error: 2.10e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1890 | Mean-Squared Error: 2.22e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1900 | Mean-Squared Error: 2.31e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1910 | Mean-Squared Error: 2.36e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1920 | Mean-Squared Error: 2.35e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1930 | Mean-Squared Error: 2.29e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1940 | Mean-Squared Error: 2.19e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1950 | Mean-Squared Error: 2.63e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1960 | Mean-Squared Error: 3.98e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1970 | Mean-Squared Error: 3.39e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1980 | Mean-Squared Error: 1.94e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1990 | Mean-Squared Error: 1.15e-16 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Iteration 1999 | Mean-Squared Error: 9.56e-17 | Uniformity: 77.45% | Min/Max ratio: 0.410
# Optimization finished in 6.65 seconds.

# %% [markdown]
# Final array

# %%
W2 = np.ones((10,10))
spacing_um = 5.0

w_n, theta_n, x_n2, y_n2 = PM.generate_weighted_array(W2, spacing_um, init_phase_randomness=1.0, angle_deg=2.5)
w_n = gauss2d(x_n2, y_n2, A, x0, y0, sx, sy, offset)

terms2 = [w_n, theta_n, x_n2, y_n2]
pm_array2, terms2, _ = PM.superposition_optimization(terms2, max_iter=2000, damping=0.5, verbose=True)
# Out:
# --- Target Generation ---
# Grid: 10x10
# Spacing: 5.0 um
# --- Starting GPU Superposition Phase Retrieval ---
# Iteration 000 | Mean-Squared Error: 1.80e-05 | Uniformity: 49.85% | Min/Max ratio: 0.036
# Iteration 010 | Mean-Squared Error: 1.60e-07 | Uniformity: 82.90% | Min/Max ratio: 0.460
# Iteration 020 | Mean-Squared Error: 9.01e-09 | Uniformity: 83.71% | Min/Max ratio: 0.531
# Iteration 030 | Mean-Squared Error: 1.00e-09 | Uniformity: 83.54% | Min/Max ratio: 0.529
# Iteration 040 | Mean-Squared Error: 1.41e-09 | Uniformity: 83.53% | Min/Max ratio: 0.529
# Iteration 050 | Mean-Squared Error: 1.17e-09 | Uniformity: 83.55% | Min/Max ratio: 0.530
# Iteration 060 | Mean-Squared Error: 1.05e-09 | Uniformity: 83.58% | Min/Max ratio: 0.530
# Iteration 070 | Mean-Squared Error: 1.57e-09 | Uniformity: 83.65% | Min/Max ratio: 0.531
# Iteration 080 | Mean-Squared Error: 1.35e-09 | Uniformity: 83.65% | Min/Max ratio: 0.529
# Iteration 090 | Mean-Squared Error: 1.25e-09 | Uniformity: 83.60% | Min/Max ratio: 0.529
# Iteration 100 | Mean-Squared Error: 1.35e-09 | Uniformity: 83.59% | Min/Max ratio: 0.530
# Iteration 110 | Mean-Squared Error: 8.74e-10 | Uniformity: 83.60% | Min/Max ratio: 0.531
# Iteration 120 | Mean-Squared Error: 5.53e-10 | Uniformity: 83.61% | Min/Max ratio: 0.530
# Iteration 130 | Mean-Squared Error: 4.04e-10 | Uniformity: 83.60% | Min/Max ratio: 0.529
# Iteration 140 | Mean-Squared Error: 2.33e-10 | Uniformity: 83.59% | Min/Max ratio: 0.528
# Iteration 150 | Mean-Squared Error: 2.00e-10 | Uniformity: 83.57% | Min/Max ratio: 0.528
# Iteration 160 | Mean-Squared Error: 3.09e-10 | Uniformity: 83.55% | Min/Max ratio: 0.527
# Iteration 170 | Mean-Squared Error: 5.18e-10 | Uniformity: 83.54% | Min/Max ratio: 0.526
# Iteration 180 | Mean-Squared Error: 7.65e-10 | Uniformity: 83.54% | Min/Max ratio: 0.526
# Iteration 190 | Mean-Squared Error: 9.09e-10 | Uniformity: 83.57% | Min/Max ratio: 0.526
# Iteration 200 | Mean-Squared Error: 1.02e-09 | Uniformity: 83.60% | Min/Max ratio: 0.527
# Iteration 210 | Mean-Squared Error: 1.40e-09 | Uniformity: 83.61% | Min/Max ratio: 0.529
# Iteration 220 | Mean-Squared Error: 1.83e-09 | Uniformity: 83.56% | Min/Max ratio: 0.531
# Iteration 230 | Mean-Squared Error: 1.69e-09 | Uniformity: 83.53% | Min/Max ratio: 0.531
# Iteration 240 | Mean-Squared Error: 7.42e-09 | Uniformity: 83.57% | Min/Max ratio: 0.528
# Iteration 250 | Mean-Squared Error: 4.72e-09 | Uniformity: 83.66% | Min/Max ratio: 0.523
# Iteration 260 | Mean-Squared Error: 1.34e-09 | Uniformity: 83.59% | Min/Max ratio: 0.528
# Iteration 270 | Mean-Squared Error: 8.30e-10 | Uniformity: 83.54% | Min/Max ratio: 0.530
# Iteration 280 | Mean-Squared Error: 1.08e-09 | Uniformity: 83.49% | Min/Max ratio: 0.529
# Iteration 290 | Mean-Squared Error: 9.12e-10 | Uniformity: 83.48% | Min/Max ratio: 0.530
# Iteration 300 | Mean-Squared Error: 6.03e-10 | Uniformity: 83.50% | Min/Max ratio: 0.529
# Iteration 310 | Mean-Squared Error: 4.20e-10 | Uniformity: 83.53% | Min/Max ratio: 0.528
# Iteration 320 | Mean-Squared Error: 4.98e-10 | Uniformity: 83.54% | Min/Max ratio: 0.528
# Iteration 330 | Mean-Squared Error: 5.11e-10 | Uniformity: 83.55% | Min/Max ratio: 0.529
# Iteration 340 | Mean-Squared Error: 4.11e-10 | Uniformity: 83.56% | Min/Max ratio: 0.529
# Iteration 350 | Mean-Squared Error: 2.75e-10 | Uniformity: 83.56% | Min/Max ratio: 0.529
# Iteration 360 | Mean-Squared Error: 1.38e-10 | Uniformity: 83.57% | Min/Max ratio: 0.529
# Iteration 370 | Mean-Squared Error: 5.89e-11 | Uniformity: 83.57% | Min/Max ratio: 0.529
# Iteration 380 | Mean-Squared Error: 2.57e-11 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 390 | Mean-Squared Error: 1.08e-11 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 400 | Mean-Squared Error: 4.96e-12 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 410 | Mean-Squared Error: 2.33e-12 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 420 | Mean-Squared Error: 1.03e-12 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 430 | Mean-Squared Error: 4.58e-13 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 440 | Mean-Squared Error: 2.18e-13 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 450 | Mean-Squared Error: 1.08e-13 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 460 | Mean-Squared Error: 5.33e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 470 | Mean-Squared Error: 2.37e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 480 | Mean-Squared Error: 1.23e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 490 | Mean-Squared Error: 1.31e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 500 | Mean-Squared Error: 1.17e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 510 | Mean-Squared Error: 6.45e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 520 | Mean-Squared Error: 9.80e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 530 | Mean-Squared Error: 8.06e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 540 | Mean-Squared Error: 7.43e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 550 | Mean-Squared Error: 7.36e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 560 | Mean-Squared Error: 5.32e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 570 | Mean-Squared Error: 6.58e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 580 | Mean-Squared Error: 2.25e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 590 | Mean-Squared Error: 1.23e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 600 | Mean-Squared Error: 8.87e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 610 | Mean-Squared Error: 7.44e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 620 | Mean-Squared Error: 1.02e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 630 | Mean-Squared Error: 1.07e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 640 | Mean-Squared Error: 1.41e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 650 | Mean-Squared Error: 7.56e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 660 | Mean-Squared Error: 6.74e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 670 | Mean-Squared Error: 7.45e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 680 | Mean-Squared Error: 8.52e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 690 | Mean-Squared Error: 9.84e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 700 | Mean-Squared Error: 8.75e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 710 | Mean-Squared Error: 4.22e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 720 | Mean-Squared Error: 1.23e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 730 | Mean-Squared Error: 7.63e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 740 | Mean-Squared Error: 6.26e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 750 | Mean-Squared Error: 5.72e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 760 | Mean-Squared Error: 5.46e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 770 | Mean-Squared Error: 1.06e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 780 | Mean-Squared Error: 4.51e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 790 | Mean-Squared Error: 6.29e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 800 | Mean-Squared Error: 7.74e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 810 | Mean-Squared Error: 6.27e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 820 | Mean-Squared Error: 1.03e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 830 | Mean-Squared Error: 5.44e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 840 | Mean-Squared Error: 9.33e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 850 | Mean-Squared Error: 8.75e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 860 | Mean-Squared Error: 1.86e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 870 | Mean-Squared Error: 8.19e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 880 | Mean-Squared Error: 2.91e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 890 | Mean-Squared Error: 7.15e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 900 | Mean-Squared Error: 9.11e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 910 | Mean-Squared Error: 1.03e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 920 | Mean-Squared Error: 1.04e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 930 | Mean-Squared Error: 8.80e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 940 | Mean-Squared Error: 5.37e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 950 | Mean-Squared Error: 6.08e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 960 | Mean-Squared Error: 8.38e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 970 | Mean-Squared Error: 5.54e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 980 | Mean-Squared Error: 4.01e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 990 | Mean-Squared Error: 1.20e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1000 | Mean-Squared Error: 1.02e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1010 | Mean-Squared Error: 9.28e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1020 | Mean-Squared Error: 5.19e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1030 | Mean-Squared Error: 4.39e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1040 | Mean-Squared Error: 6.88e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1050 | Mean-Squared Error: 4.83e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1060 | Mean-Squared Error: 5.62e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1070 | Mean-Squared Error: 6.11e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1080 | Mean-Squared Error: 6.20e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1090 | Mean-Squared Error: 5.31e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1100 | Mean-Squared Error: 5.24e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1110 | Mean-Squared Error: 4.41e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1120 | Mean-Squared Error: 3.69e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1130 | Mean-Squared Error: 4.61e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1140 | Mean-Squared Error: 8.53e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1150 | Mean-Squared Error: 7.33e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1160 | Mean-Squared Error: 8.47e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1170 | Mean-Squared Error: 7.60e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1180 | Mean-Squared Error: 5.15e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1190 | Mean-Squared Error: 4.88e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1200 | Mean-Squared Error: 6.54e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1210 | Mean-Squared Error: 6.95e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1220 | Mean-Squared Error: 8.33e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1230 | Mean-Squared Error: 7.89e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1240 | Mean-Squared Error: 7.49e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1250 | Mean-Squared Error: 6.16e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1260 | Mean-Squared Error: 5.17e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1270 | Mean-Squared Error: 5.54e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1280 | Mean-Squared Error: 5.77e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1290 | Mean-Squared Error: 5.24e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1300 | Mean-Squared Error: 6.91e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1310 | Mean-Squared Error: 5.13e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1320 | Mean-Squared Error: 1.99e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1330 | Mean-Squared Error: 5.98e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1340 | Mean-Squared Error: 4.18e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1350 | Mean-Squared Error: 4.18e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1360 | Mean-Squared Error: 4.76e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1370 | Mean-Squared Error: 3.98e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1380 | Mean-Squared Error: 5.06e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1390 | Mean-Squared Error: 7.82e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1400 | Mean-Squared Error: 1.46e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1410 | Mean-Squared Error: 7.38e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1420 | Mean-Squared Error: 5.03e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1430 | Mean-Squared Error: 4.15e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1440 | Mean-Squared Error: 4.71e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1450 | Mean-Squared Error: 6.02e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1460 | Mean-Squared Error: 8.85e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1470 | Mean-Squared Error: 1.84e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1480 | Mean-Squared Error: 8.32e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1490 | Mean-Squared Error: 7.07e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1500 | Mean-Squared Error: 4.62e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1510 | Mean-Squared Error: 4.20e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1520 | Mean-Squared Error: 3.96e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1530 | Mean-Squared Error: 4.89e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1540 | Mean-Squared Error: 7.05e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1550 | Mean-Squared Error: 7.82e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1560 | Mean-Squared Error: 9.93e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1570 | Mean-Squared Error: 9.15e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1580 | Mean-Squared Error: 6.09e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1590 | Mean-Squared Error: 4.82e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1600 | Mean-Squared Error: 5.38e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1610 | Mean-Squared Error: 4.34e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1620 | Mean-Squared Error: 4.43e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1630 | Mean-Squared Error: 1.89e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1640 | Mean-Squared Error: 3.89e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1650 | Mean-Squared Error: 7.76e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1660 | Mean-Squared Error: 5.58e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1670 | Mean-Squared Error: 3.10e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1680 | Mean-Squared Error: 2.86e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1690 | Mean-Squared Error: 2.94e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1700 | Mean-Squared Error: 5.49e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1710 | Mean-Squared Error: 7.66e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1720 | Mean-Squared Error: 1.21e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1730 | Mean-Squared Error: 4.33e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1740 | Mean-Squared Error: 5.46e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1750 | Mean-Squared Error: 5.03e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1760 | Mean-Squared Error: 3.73e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1770 | Mean-Squared Error: 3.07e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1780 | Mean-Squared Error: 2.69e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1790 | Mean-Squared Error: 2.75e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1800 | Mean-Squared Error: 5.77e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1810 | Mean-Squared Error: 6.54e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1820 | Mean-Squared Error: 1.04e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1830 | Mean-Squared Error: 6.74e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1840 | Mean-Squared Error: 7.69e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1850 | Mean-Squared Error: 1.27e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1860 | Mean-Squared Error: 5.38e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1870 | Mean-Squared Error: 3.28e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1880 | Mean-Squared Error: 5.81e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1890 | Mean-Squared Error: 5.97e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1900 | Mean-Squared Error: 3.77e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1910 | Mean-Squared Error: 6.11e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1920 | Mean-Squared Error: 5.51e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1930 | Mean-Squared Error: 4.99e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1940 | Mean-Squared Error: 5.31e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1950 | Mean-Squared Error: 3.92e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1960 | Mean-Squared Error: 2.56e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1970 | Mean-Squared Error: 3.91e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1980 | Mean-Squared Error: 4.46e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1990 | Mean-Squared Error: 4.74e-15 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Iteration 1999 | Mean-Squared Error: 3.55e-14 | Uniformity: 83.57% | Min/Max ratio: 0.530
# Optimization finished in 3.84 seconds.

# %% [markdown]
# Load initial array onto the SLM

# %%
pm_composite = PM.superimpose([pm_array1, PM.fresnel, PM.blaze, PM.zernike])
pm_composite_uint8 = PM.transform_phase_8bit(pm_composite).get()
slm.update_mask(pm_composite_uint8)

# %% [markdown]
# ## Baseline - Load and Image Initial Array

# %%
# Experiment and camera setup
n_iterations = 100
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
hamcam.setup_acquisition("snap", n_iterations * 2)
hamcam.start_acquisition()
exp.start_motmaster_experiment({
    "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
    "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
    "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"),
    "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
    "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"),
    "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
    "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"),
    "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
    "tMOTShimXccValue": ExpParams.get_parameter("tMOTShimXccValue"), "tMOTShimYccValue": ExpParams.get_parameter("tMOTShimYccValue"), "tMOTShimZccValue": ExpParams.get_parameter("tMOTShimZccValue"),
    "tMolassesShimXccValue": ExpParams.get_parameter("tMolassesShimXccValue"), "tMolassesShimYccValue": ExpParams.get_parameter("tMolassesShimYccValue"), "tMolassesShimZccValue": ExpParams.get_parameter("tMolassesShimZccValue"),
    "tTweezerSetVVA0": 0.0, "tTweezerSetVVA1": 0.0,
    "BackgroundDrop": 1})

imgs = hamcam.acquire_n_frames(n_iterations * 2)
imgs1, imgs2 = imgs[::2], imgs[1::2]
img_average = an.tweezer_show_bg_subtracted(imgs1, imgs2, cmap='magma', show=True, vmaxfactor=0.6, show_grid=True)

ExpParams.set_parameter("conversion_factor", hamcam.dcam.get_attribute_value("CONVERSION FACTOR COEFF"))
ExpParams.set_parameter("conversion_offset", hamcam.dcam.get_attribute_value("CONVERSION FACTOR OFFSET"))
ExpParams.save_parameters()
# Out:
# Parameter 'conversion_factor' set to 0.009508957628343926.
# Parameter 'conversion_offset' set to 1917.159423828125.
# Parameters saved.

# %%
feature_size, window = 10, 5
img_average_filtered = an.morphological_tophat_high_pass(img_average, feature_size=feature_size)
grid_positions, detection_threshold = an.detect_trap_sites(img_average_filtered, 14*14, detection_step=100)
an.set_array_centre(grid_positions)
grid_positions = an.index_grid_positions(grid_positions, x_n1, y_n1)
an.visualize_results(img_average_filtered, grid_positions, margin=50, window_size=window, threshold=detection_threshold*1.5, vmaxfactor=0.5, bin_sharpness=20, bin_thresh_factor=0.6)
imgs_n_filtered = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]
photons, loading_probabilities, threshold_1, fidelity = an.get_array_loading_statistics(imgs_n_filtered, grid_positions, threshold=100, window_size=5, binning=60, 
                                                                                        show_histogram=True, threshold_detection=True, verbose=True, show_site_labels=True)
# Out:
# Looking for trap sites...
# 196 Atoms Detected.
# Parameter 'x_centre' set to 135.8265306122449.
# Parameter 'y_centre' set to 131.84183673469389.
# Parameters saved.
# Trap (0) Loading Probability : 50.00 %
# Trap (1) Loading Probability : 61.00 %
# Trap (2) Loading Probability : 49.00 %
# Trap (3) Loading Probability : 55.00 %
# Trap (4) Loading Probability : 53.00 %
# Trap (5) Loading Probability : 54.00 %
# Trap (6) Loading Probability : 51.00 %
# Trap (7) Loading Probability : 51.00 %
# Trap (8) Loading Probability : 50.00 %
# Trap (9) Loading Probability : 58.00 %
# Trap (10) Loading Probability : 62.00 %
# Trap (11) Loading Probability : 46.00 %
# Trap (12) Loading Probability : 48.00 %
# Trap (13) Loading Probability : 48.00 %
# Trap (14) Loading Probability : 56.00 %
# Trap (15) Loading Probability : 58.00 %
# Trap (16) Loading Probability : 54.00 %
# Trap (17) Loading Probability : 59.00 %
# Trap (18) Loading Probability : 66.00 %
# Trap (19) Loading Probability : 54.00 %
# Trap (20) Loading Probability : 58.00 %
# Trap (21) Loading Probability : 60.00 %
# Trap (22) Loading Probability : 62.00 %
# Trap (23) Loading Probability : 48.00 %
# Trap (24) Loading Probability : 51.00 %
# Trap (25) Loading Probability : 55.00 %
# Trap (26) Loading Probability : 57.00 %
# Trap (27) Loading Probability : 52.00 %
# Trap (28) Loading Probability : 51.00 %
# Trap (29) Loading Probability : 53.00 %
# Trap (30) Loading Probability : 57.00 %
# Trap (31) Loading Probability : 48.00 %
# Trap (32) Loading Probability : 60.00 %
# Trap (33) Loading Probability : 57.00 %
# Trap (34) Loading Probability : 62.00 %
# Trap (35) Loading Probability : 53.00 %
# Trap (36) Loading Probability : 57.00 %
# Trap (37) Loading Probability : 56.00 %
# Trap (38) Loading Probability : 53.00 %
# Trap (39) Loading Probability : 54.00 %
# Trap (40) Loading Probability : 52.00 %
# Trap (41) Loading Probability : 51.00 %
# Trap (42) Loading Probability : 49.00 %
# Trap (43) Loading Probability : 53.00 %
# Trap (44) Loading Probability : 55.00 %
# Trap (45) Loading Probability : 49.00 %
# Trap (46) Loading Probability : 56.00 %
# Trap (47) Loading Probability : 58.00 %
# Trap (48) Loading Probability : 67.00 %
# Trap (49) Loading Probability : 49.00 %
# Trap (50) Loading Probability : 57.00 %
# Trap (51) Loading Probability : 58.00 %
# Trap (52) Loading Probability : 54.00 %
# Trap (53) Loading Probability : 61.00 %
# Trap (54) Loading Probability : 55.00 %
# Trap (55) Loading Probability : 62.00 %
# Trap (56) Loading Probability : 66.00 %
# Trap (57) Loading Probability : 59.00 %
# Trap (58) Loading Probability : 59.00 %
# Trap (59) Loading Probability : 54.00 %
# Trap (60) Loading Probability : 59.00 %
# Trap (61) Loading Probability : 63.00 %
# Trap (62) Loading Probability : 53.00 %
# Trap (63) Loading Probability : 61.00 %
# Trap (64) Loading Probability : 62.00 %
# Trap (65) Loading Probability : 61.00 %
# Trap (66) Loading Probability : 51.00 %
# Trap (67) Loading Probability : 50.00 %
# Trap (68) Loading Probability : 51.00 %
# Trap (69) Loading Probability : 62.00 %
# Trap (70) Loading Probability : 58.00 %
# Trap (71) Loading Probability : 52.00 %
# Trap (72) Loading Probability : 59.00 %
# Trap (73) Loading Probability : 51.00 %
# Trap (74) Loading Probability : 56.00 %
# Trap (75) Loading Probability : 60.00 %
# Trap (76) Loading Probability : 65.00 %
# Trap (77) Loading Probability : 57.00 %
# Trap (78) Loading Probability : 53.00 %
# Trap (79) Loading Probability : 57.00 %
# Trap (80) Loading Probability : 51.00 %
# Trap (81) Loading Probability : 58.00 %
# Trap (82) Loading Probability : 61.00 %
# Trap (83) Loading Probability : 61.00 %
# Trap (84) Loading Probability : 57.00 %
# Trap (85) Loading Probability : 59.00 %
# Trap (86) Loading Probability : 68.00 %
# Trap (87) Loading Probability : 54.00 %
# Trap (88) Loading Probability : 53.00 %
# Trap (89) Loading Probability : 57.00 %
# Trap (90) Loading Probability : 51.00 %
# Trap (91) Loading Probability : 59.00 %
# Trap (92) Loading Probability : 62.00 %
# Trap (93) Loading Probability : 54.00 %
# Trap (94) Loading Probability : 60.00 %
# Trap (95) Loading Probability : 61.00 %
# Trap (96) Loading Probability : 58.00 %
# Trap (97) Loading Probability : 61.00 %
# Trap (98) Loading Probability : 59.00 %
# Trap (99) Loading Probability : 60.00 %
# Trap (100) Loading Probability : 54.00 %
# Trap (101) Loading Probability : 55.00 %
# Trap (102) Loading Probability : 56.00 %
# Trap (103) Loading Probability : 66.00 %
# Trap (104) Loading Probability : 53.00 %
# Trap (105) Loading Probability : 62.00 %
# Trap (106) Loading Probability : 52.00 %
# Trap (107) Loading Probability : 58.00 %
# Trap (108) Loading Probability : 50.00 %
# Trap (109) Loading Probability : 53.00 %
# Trap (110) Loading Probability : 63.00 %
# Trap (111) Loading Probability : 55.00 %
# Trap (112) Loading Probability : 58.00 %
# Trap (113) Loading Probability : 60.00 %
# Trap (114) Loading Probability : 56.00 %
# Trap (115) Loading Probability : 59.00 %
# Trap (116) Loading Probability : 56.00 %
# Trap (117) Loading Probability : 58.00 %
# Trap (118) Loading Probability : 57.00 %
# Trap (119) Loading Probability : 55.00 %
# Trap (120) Loading Probability : 60.00 %
# Trap (121) Loading Probability : 56.00 %
# Trap (122) Loading Probability : 61.00 %
# Trap (123) Loading Probability : 55.00 %
# Trap (124) Loading Probability : 60.00 %
# Trap (125) Loading Probability : 60.00 %
# Trap (126) Loading Probability : 60.00 %
# Trap (127) Loading Probability : 59.00 %
# Trap (128) Loading Probability : 66.00 %
# Trap (129) Loading Probability : 67.00 %
# Trap (130) Loading Probability : 50.00 %
# Trap (131) Loading Probability : 64.00 %
# Trap (132) Loading Probability : 60.00 %
# Trap (133) Loading Probability : 56.00 %
# Trap (134) Loading Probability : 61.00 %
# Trap (135) Loading Probability : 51.00 %
# Trap (136) Loading Probability : 60.00 %
# Trap (137) Loading Probability : 52.00 %
# Trap (138) Loading Probability : 43.00 %
# Trap (139) Loading Probability : 47.00 %
# Trap (140) Loading Probability : 57.00 %
# Trap (141) Loading Probability : 67.00 %
# Trap (142) Loading Probability : 59.00 %
# Trap (143) Loading Probability : 60.00 %
# Trap (144) Loading Probability : 62.00 %
# Trap (145) Loading Probability : 61.00 %
# Trap (146) Loading Probability : 58.00 %
# Trap (147) Loading Probability : 57.00 %
# Trap (148) Loading Probability : 63.00 %
# Trap (149) Loading Probability : 57.00 %
# Trap (150) Loading Probability : 65.00 %
# Trap (151) Loading Probability : 60.00 %
# Trap (152) Loading Probability : 56.00 %
# Trap (153) Loading Probability : 55.00 %
# Trap (154) Loading Probability : 52.00 %
# Trap (155) Loading Probability : 63.00 %
# Trap (156) Loading Probability : 55.00 %
# Trap (157) Loading Probability : 57.00 %
# Trap (158) Loading Probability : 52.00 %
# Trap (159) Loading Probability : 52.00 %
# Trap (160) Loading Probability : 47.00 %
# Trap (161) Loading Probability : 61.00 %
# Trap (162) Loading Probability : 57.00 %
# Trap (163) Loading Probability : 48.00 %
# Trap (164) Loading Probability : 53.00 %
# Trap (165) Loading Probability : 53.00 %
# Trap (166) Loading Probability : 59.00 %
# Trap (167) Loading Probability : 53.00 %
# Trap (168) Loading Probability : 58.00 %
# Trap (169) Loading Probability : 63.00 %
# Trap (170) Loading Probability : 53.00 %
# Trap (171) Loading Probability : 68.00 %
# Trap (172) Loading Probability : 52.00 %
# Trap (173) Loading Probability : 55.00 %
# Trap (174) Loading Probability : 59.00 %
# Trap (175) Loading Probability : 59.00 %
# Trap (176) Loading Probability : 51.00 %
# Trap (177) Loading Probability : 47.00 %
# Trap (178) Loading Probability : 52.00 %
# Trap (179) Loading Probability : 49.00 %
# Trap (180) Loading Probability : 45.00 %
# Trap (181) Loading Probability : 54.00 %
# Trap (182) Loading Probability : 62.00 %
# Trap (183) Loading Probability : 59.00 %
# Trap (184) Loading Probability : 57.00 %
# Trap (185) Loading Probability : 64.00 %
# Trap (186) Loading Probability : 55.00 %
# Trap (187) Loading Probability : 53.00 %
# Trap (188) Loading Probability : 62.00 %
# Trap (189) Loading Probability : 57.00 %
# Trap (190) Loading Probability : 62.00 %
# Trap (191) Loading Probability : 57.00 %
# Trap (192) Loading Probability : 57.00 %
# Trap (193) Loading Probability : 51.00 %
# Trap (194) Loading Probability : 54.00 %
# Trap (195) Loading Probability : 52.00 %
# Detected Loading Threshold: 80.02 photons
# Std dev of Loading Probabilities: 8.74 %
# Mean Loading Probability: 56.46 %
# Detection Fidelity: 99.11 %
# Mean Background Photon Count: 43.24 photons, Variance: 202.15 photons^2
# Mean Signal Photon Count: 151.15 photons, Variance: 991.36 photons^2

# %%
# Analyse images (fliplr) with indexed grid positions - PSF
psf_window = 9

# Templates come from the raw frames - the matched filter needs no top-hat.
scorer = an.SiteScorer.from_images(imgs1, grid_positions, window_size=psf_window)
photons, loading_probabilities, threshold_1, fidelity = an.get_array_loading_statistics(
    imgs1, grid_positions, scorer=scorer, threshold_detection=True, binning=60)

scorer.threshold = threshold_1 * 1.0
print(f"PSF threshold {scorer.threshold:.2f} photons, detection fidelity {fidelity*100:.3f} %")
# Out:
# Trap (0) Loading Probability : 54.00 %
# Trap (1) Loading Probability : 63.00 %
# Trap (2) Loading Probability : 50.00 %
# Trap (3) Loading Probability : 56.00 %
# Trap (4) Loading Probability : 55.00 %
# Trap (5) Loading Probability : 55.00 %
# Trap (6) Loading Probability : 52.00 %
# Trap (7) Loading Probability : 51.00 %
# Trap (8) Loading Probability : 51.00 %
# Trap (9) Loading Probability : 58.00 %
# Trap (10) Loading Probability : 66.00 %
# Trap (11) Loading Probability : 52.00 %
# Trap (12) Loading Probability : 53.00 %
# Trap (13) Loading Probability : 54.00 %
# Trap (14) Loading Probability : 61.00 %
# Trap (15) Loading Probability : 58.00 %
# Trap (16) Loading Probability : 55.00 %
# Trap (17) Loading Probability : 58.00 %
# Trap (18) Loading Probability : 66.00 %
# Trap (19) Loading Probability : 53.00 %
# Trap (20) Loading Probability : 61.00 %
# Trap (21) Loading Probability : 60.00 %
# Trap (22) Loading Probability : 62.00 %
# Trap (23) Loading Probability : 49.00 %
# Trap (24) Loading Probability : 54.00 %
# Trap (25) Loading Probability : 55.00 %
# Trap (26) Loading Probability : 61.00 %
# Trap (27) Loading Probability : 54.00 %
# Trap (28) Loading Probability : 54.00 %
# Trap (29) Loading Probability : 53.00 %
# Trap (30) Loading Probability : 58.00 %
# Trap (31) Loading Probability : 49.00 %
# Trap (32) Loading Probability : 58.00 %
# Trap (33) Loading Probability : 57.00 %
# Trap (34) Loading Probability : 62.00 %
# Trap (35) Loading Probability : 52.00 %
# Trap (36) Loading Probability : 54.00 %
# Trap (37) Loading Probability : 56.00 %
# Trap (38) Loading Probability : 53.00 %
# Trap (39) Loading Probability : 53.00 %
# Trap (40) Loading Probability : 52.00 %
# Trap (41) Loading Probability : 53.00 %
# Trap (42) Loading Probability : 50.00 %
# Trap (43) Loading Probability : 52.00 %
# Trap (44) Loading Probability : 56.00 %
# Trap (45) Loading Probability : 48.00 %
# Trap (46) Loading Probability : 53.00 %
# Trap (47) Loading Probability : 58.00 %
# Trap (48) Loading Probability : 66.00 %
# Trap (49) Loading Probability : 49.00 %
# Trap (50) Loading Probability : 55.00 %
# Trap (51) Loading Probability : 58.00 %
# Trap (52) Loading Probability : 54.00 %
# Trap (53) Loading Probability : 61.00 %
# Trap (54) Loading Probability : 58.00 %
# Trap (55) Loading Probability : 60.00 %
# Trap (56) Loading Probability : 68.00 %
# Trap (57) Loading Probability : 55.00 %
# Trap (58) Loading Probability : 58.00 %
# Trap (59) Loading Probability : 51.00 %
# Trap (60) Loading Probability : 59.00 %
# Trap (61) Loading Probability : 62.00 %
# Trap (62) Loading Probability : 54.00 %
# Trap (63) Loading Probability : 60.00 %
# Trap (64) Loading Probability : 62.00 %
# Trap (65) Loading Probability : 60.00 %
# Trap (66) Loading Probability : 51.00 %
# Trap (67) Loading Probability : 48.00 %
# Trap (68) Loading Probability : 51.00 %
# Trap (69) Loading Probability : 61.00 %
# Trap (70) Loading Probability : 58.00 %
# Trap (71) Loading Probability : 52.00 %
# Trap (72) Loading Probability : 57.00 %
# Trap (73) Loading Probability : 50.00 %
# Trap (74) Loading Probability : 54.00 %
# Trap (75) Loading Probability : 58.00 %
# Trap (76) Loading Probability : 63.00 %
# Trap (77) Loading Probability : 55.00 %
# Trap (78) Loading Probability : 53.00 %
# Trap (79) Loading Probability : 57.00 %
# Trap (80) Loading Probability : 51.00 %
# Trap (81) Loading Probability : 58.00 %
# Trap (82) Loading Probability : 60.00 %
# Trap (83) Loading Probability : 61.00 %
# Trap (84) Loading Probability : 57.00 %
# Trap (85) Loading Probability : 59.00 %
# Trap (86) Loading Probability : 68.00 %
# Trap (87) Loading Probability : 52.00 %
# Trap (88) Loading Probability : 49.00 %
# Trap (89) Loading Probability : 53.00 %
# Trap (90) Loading Probability : 49.00 %
# Trap (91) Loading Probability : 53.00 %
# Trap (92) Loading Probability : 61.00 %
# Trap (93) Loading Probability : 54.00 %
# Trap (94) Loading Probability : 59.00 %
# Trap (95) Loading Probability : 60.00 %
# Trap (96) Loading Probability : 59.00 %
# Trap (97) Loading Probability : 61.00 %
# Trap (98) Loading Probability : 59.00 %
# Trap (99) Loading Probability : 58.00 %
# Trap (100) Loading Probability : 55.00 %
# Trap (101) Loading Probability : 54.00 %
# Trap (102) Loading Probability : 54.00 %
# Trap (103) Loading Probability : 65.00 %
# Trap (104) Loading Probability : 52.00 %
# Trap (105) Loading Probability : 62.00 %
# Trap (106) Loading Probability : 45.00 %
# Trap (107) Loading Probability : 57.00 %
# Trap (108) Loading Probability : 50.00 %
# Trap (109) Loading Probability : 53.00 %
# Trap (110) Loading Probability : 63.00 %
# Trap (111) Loading Probability : 56.00 %
# Trap (112) Loading Probability : 58.00 %
# Trap (113) Loading Probability : 60.00 %
# Trap (114) Loading Probability : 54.00 %
# Trap (115) Loading Probability : 60.00 %
# Trap (116) Loading Probability : 54.00 %
# Trap (117) Loading Probability : 57.00 %
# Trap (118) Loading Probability : 57.00 %
# Trap (119) Loading Probability : 51.00 %
# Trap (120) Loading Probability : 59.00 %
# Trap (121) Loading Probability : 56.00 %
# Trap (122) Loading Probability : 61.00 %
# Trap (123) Loading Probability : 56.00 %
# Trap (124) Loading Probability : 60.00 %
# Trap (125) Loading Probability : 59.00 %
# Trap (126) Loading Probability : 60.00 %
# Trap (127) Loading Probability : 59.00 %
# Trap (128) Loading Probability : 64.00 %
# Trap (129) Loading Probability : 65.00 %
# Trap (130) Loading Probability : 50.00 %
# Trap (131) Loading Probability : 62.00 %
# Trap (132) Loading Probability : 60.00 %
# Trap (133) Loading Probability : 56.00 %
# Trap (134) Loading Probability : 59.00 %
# Trap (135) Loading Probability : 52.00 %
# Trap (136) Loading Probability : 60.00 %
# Trap (137) Loading Probability : 51.00 %
# Trap (138) Loading Probability : 43.00 %
# Trap (139) Loading Probability : 47.00 %
# Trap (140) Loading Probability : 57.00 %
# Trap (141) Loading Probability : 67.00 %
# Trap (142) Loading Probability : 59.00 %
# Trap (143) Loading Probability : 58.00 %
# Trap (144) Loading Probability : 62.00 %
# Trap (145) Loading Probability : 61.00 %
# Trap (146) Loading Probability : 58.00 %
# Trap (147) Loading Probability : 56.00 %
# Trap (148) Loading Probability : 61.00 %
# Trap (149) Loading Probability : 55.00 %
# Trap (150) Loading Probability : 64.00 %
# Trap (151) Loading Probability : 60.00 %
# Trap (152) Loading Probability : 56.00 %
# Trap (153) Loading Probability : 55.00 %
# Trap (154) Loading Probability : 55.00 %
# Trap (155) Loading Probability : 65.00 %
# Trap (156) Loading Probability : 55.00 %
# Trap (157) Loading Probability : 57.00 %
# Trap (158) Loading Probability : 53.00 %
# Trap (159) Loading Probability : 51.00 %
# Trap (160) Loading Probability : 47.00 %
# Trap (161) Loading Probability : 60.00 %
# Trap (162) Loading Probability : 56.00 %
# Trap (163) Loading Probability : 46.00 %
# Trap (164) Loading Probability : 53.00 %
# Trap (165) Loading Probability : 54.00 %
# Trap (166) Loading Probability : 59.00 %
# Trap (167) Loading Probability : 53.00 %
# Trap (168) Loading Probability : 58.00 %
# Trap (169) Loading Probability : 64.00 %
# Trap (170) Loading Probability : 53.00 %
# Trap (171) Loading Probability : 67.00 %
# Trap (172) Loading Probability : 52.00 %
# Trap (173) Loading Probability : 55.00 %
# Trap (174) Loading Probability : 58.00 %
# Trap (175) Loading Probability : 59.00 %
# Trap (176) Loading Probability : 52.00 %
# Trap (177) Loading Probability : 47.00 %
# Trap (178) Loading Probability : 52.00 %
# Trap (179) Loading Probability : 49.00 %
# Trap (180) Loading Probability : 45.00 %
# Trap (181) Loading Probability : 54.00 %
# Trap (182) Loading Probability : 62.00 %
# Trap (183) Loading Probability : 59.00 %
# Trap (184) Loading Probability : 57.00 %
# Trap (185) Loading Probability : 65.00 %
# Trap (186) Loading Probability : 55.00 %
# Trap (187) Loading Probability : 53.00 %
# Trap (188) Loading Probability : 62.00 %
# Trap (189) Loading Probability : 58.00 %
# Trap (190) Loading Probability : 63.00 %
# Trap (191) Loading Probability : 57.00 %
# Trap (192) Loading Probability : 57.00 %
# Trap (193) Loading Probability : 51.00 %
# Trap (194) Loading Probability : 56.00 %
# Trap (195) Loading Probability : 53.00 %
# Detected Loading Threshold: 19.77 photons
# Std dev of Loading Probabilities: 8.58 %
# Mean Loading Probability: 56.32 %
# Detection Fidelity: 99.84 %
# Mean Background Photon Count: -27.21 photons, Variance: 221.35 photons^2
# Mean Signal Photon Count: 125.86 photons, Variance: 1382.82 photons^2
# PSF threshold 19.77 photons, detection fidelity 99.843 %

# %%
# Experiment and camera setup
n_iterations = 100
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
hamcam.setup_acquisition("snap", n_iterations * 2)
hamcam.start_acquisition()
exp.start_motmaster_experiment({
    "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
    "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
    "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"),
    "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
    "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"),
    "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
    "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"),
    "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
    "tMOTShimXccValue": ExpParams.get_parameter("tMOTShimXccValue"), "tMOTShimYccValue": ExpParams.get_parameter("tMOTShimYccValue"), "tMOTShimZccValue": ExpParams.get_parameter("tMOTShimZccValue"),
    "tMolassesShimXccValue": ExpParams.get_parameter("tMolassesShimXccValue"), "tMolassesShimYccValue": ExpParams.get_parameter("tMolassesShimYccValue"), "tMolassesShimZccValue": ExpParams.get_parameter("tMolassesShimZccValue"),
    "tTweezerSetVVA0": 9.0, "tTweezerSetVVA1": 9.0, "tDelay2": 5000,
    "BackgroundDrop": 0})

imgs = hamcam.acquire_n_frames(n_iterations * 2)
imgs1, imgs2 = imgs[::2], imgs[1::2]

# %%
def extract_survival_probability(imgs1, imgs2, grid_positions, threshold='auto', window_size=5):
    if threshold == 'auto':
        pr_1, eta_1, thresh_1, fidelity_1 = an.get_array_loading_statistics(imgs1, grid_positions, scorer=scorer, threshold_detection=True, binning=60, show_histogram=False)
        pr_2, eta_2, thresh_2, fidelity_2 = an.get_array_loading_statistics(imgs2, grid_positions, scorer=scorer, threshold_detection=True, binning=60, show_histogram=False)
    else:
        pr_1, eta_1, thresh_1, fidelity_1 = an.get_array_loading_statistics(imgs1, grid_positions, scorer=scorer, threshold_detection=True, binning=60, show_histogram=False)
        pr_2, eta_2, thresh_2, fidelity_2 = an.get_array_loading_statistics(imgs2, grid_positions, scorer=scorer, threshold_detection=True, binning=60, show_histogram=False)
    survival_fractions = []
    for i in range(pr_1.shape[0]):

        pr_mat_1 = pr_1[i]
        pr_mat_2 = pr_2[i]

        pr_mat_1_binary = (pr_mat_1 > thresh_1).astype(int)
        pr_mat_2_binary = (pr_mat_2 > thresh_2).astype(int)
        survival_matrix = pr_mat_1_binary * pr_mat_2_binary

        init_occupation = pr_mat_1_binary.sum()
        final_occupation = pr_mat_2_binary.sum()
        survival_count = survival_matrix.sum()
        survival_fraction = survival_count / init_occupation if init_occupation > 0 else 0
        survival_fractions.append(survival_fraction)

    survival_probability = np.mean(survival_fractions)
    return survival_probability

# %%
imgs_filtered_1 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]
imgs_filtered_2 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs2]
baseline_survival_probability = extract_survival_probability(imgs_filtered_1, imgs_filtered_2, grid_positions, window_size=window)
out_ = an.get_array_loading_statistics(imgs_filtered_1, grid_positions, threshold_detection=True, window_size=window, binning=60, show_site_labels=True)
print(f"Baseline survival probability: {baseline_survival_probability:.4f}")
# Out:
# Detected Loading Threshold: 7.33 photons
# Std dev of Loading Probabilities: 8.71 %
# Mean Loading Probability: 57.33 %
# Detection Fidelity: 99.82 %
# Mean Background Photon Count: -25.68 photons, Variance: 108.91 photons^2
# Mean Signal Photon Count: 93.94 photons, Variance: 957.34 photons^2
# Detected Loading Threshold: 4.56 photons
# Std dev of Loading Probabilities: 8.93 %
# Mean Loading Probability: 55.90 %
# Detection Fidelity: 99.94 %
# Mean Background Photon Count: -25.68 photons, Variance: 75.82 photons^2
# Mean Signal Photon Count: 93.91 photons, Variance: 825.36 photons^2
# Trap (0) Loading Probability : 45.00 %
# Trap (1) Loading Probability : 58.00 %
# Trap (2) Loading Probability : 48.00 %
# Trap (3) Loading Probability : 54.00 %
# Trap (4) Loading Probability : 52.00 %
# Trap (5) Loading Probability : 63.00 %
# Trap (6) Loading Probability : 56.00 %
# Trap (7) Loading Probability : 54.00 %
# Trap (8) Loading Probability : 59.00 %
# Trap (9) Loading Probability : 56.00 %
# Trap (10) Loading Probability : 52.00 %
# Trap (11) Loading Probability : 73.00 %
# Trap (12) Loading Probability : 57.00 %
# Trap (13) Loading Probability : 56.00 %
# Trap (14) Loading Probability : 53.00 %
# Trap (15) Loading Probability : 61.00 %
# Trap (16) Loading Probability : 58.00 %
# Trap (17) Loading Probability : 54.00 %
# Trap (18) Loading Probability : 62.00 %
# Trap (19) Loading Probability : 54.00 %
# Trap (20) Loading Probability : 64.00 %
# Trap (21) Loading Probability : 63.00 %
# Trap (22) Loading Probability : 45.00 %
# Trap (23) Loading Probability : 54.00 %
# Trap (24) Loading Probability : 48.00 %
# Trap (25) Loading Probability : 58.00 %
# Trap (26) Loading Probability : 57.00 %
# Trap (27) Loading Probability : 51.00 %
# Trap (28) Loading Probability : 63.00 %
# Trap (29) Loading Probability : 58.00 %
# Trap (30) Loading Probability : 54.00 %
# Trap (31) Loading Probability : 68.00 %
# Trap (32) Loading Probability : 62.00 %
# Trap (33) Loading Probability : 60.00 %
# Trap (34) Loading Probability : 69.00 %
# Trap (35) Loading Probability : 62.00 %
# Trap (36) Loading Probability : 53.00 %
# Trap (37) Loading Probability : 52.00 %
# Trap (38) Loading Probability : 51.00 %
# Trap (39) Loading Probability : 54.00 %
# Trap (40) Loading Probability : 60.00 %
# Trap (41) Loading Probability : 56.00 %
# Trap (42) Loading Probability : 56.00 %
# Trap (43) Loading Probability : 60.00 %
# Trap (44) Loading Probability : 53.00 %
# Trap (45) Loading Probability : 58.00 %
# Trap (46) Loading Probability : 56.00 %
# Trap (47) Loading Probability : 60.00 %
# Trap (48) Loading Probability : 54.00 %
# Trap (49) Loading Probability : 64.00 %
# Trap (50) Loading Probability : 55.00 %
# Trap (51) Loading Probability : 60.00 %
# Trap (52) Loading Probability : 58.00 %
# Trap (53) Loading Probability : 57.00 %
# Trap (54) Loading Probability : 56.00 %
# Trap (55) Loading Probability : 54.00 %
# Trap (56) Loading Probability : 53.00 %
# Trap (57) Loading Probability : 57.00 %
# Trap (58) Loading Probability : 59.00 %
# Trap (59) Loading Probability : 64.00 %
# Trap (60) Loading Probability : 45.00 %
# Trap (61) Loading Probability : 60.00 %
# Trap (62) Loading Probability : 52.00 %
# Trap (63) Loading Probability : 66.00 %
# Trap (64) Loading Probability : 56.00 %
# Trap (65) Loading Probability : 50.00 %
# Trap (66) Loading Probability : 59.00 %
# Trap (67) Loading Probability : 60.00 %
# Trap (68) Loading Probability : 58.00 %
# Trap (69) Loading Probability : 52.00 %
# Trap (70) Loading Probability : 54.00 %
# Trap (71) Loading Probability : 59.00 %
# Trap (72) Loading Probability : 54.00 %
# Trap (73) Loading Probability : 65.00 %
# Trap (74) Loading Probability : 63.00 %
# Trap (75) Loading Probability : 51.00 %
# Trap (76) Loading Probability : 52.00 %
# Trap (77) Loading Probability : 55.00 %
# Trap (78) Loading Probability : 61.00 %
# Trap (79) Loading Probability : 53.00 %
# Trap (80) Loading Probability : 60.00 %
# Trap (81) Loading Probability : 51.00 %
# Trap (82) Loading Probability : 54.00 %
# Trap (83) Loading Probability : 52.00 %
# Trap (84) Loading Probability : 58.00 %
# Trap (85) Loading Probability : 55.00 %
# Trap (86) Loading Probability : 54.00 %
# Trap (87) Loading Probability : 63.00 %
# Trap (88) Loading Probability : 55.00 %
# Trap (89) Loading Probability : 50.00 %
# Trap (90) Loading Probability : 58.00 %
# Trap (91) Loading Probability : 51.00 %
# Trap (92) Loading Probability : 52.00 %
# Trap (93) Loading Probability : 52.00 %
# Trap (94) Loading Probability : 55.00 %
# Trap (95) Loading Probability : 65.00 %
# Trap (96) Loading Probability : 67.00 %
# Trap (97) Loading Probability : 61.00 %
# Trap (98) Loading Probability : 61.00 %
# Trap (99) Loading Probability : 53.00 %
# Trap (100) Loading Probability : 58.00 %
# Trap (101) Loading Probability : 68.00 %
# Trap (102) Loading Probability : 51.00 %
# Trap (103) Loading Probability : 55.00 %
# Trap (104) Loading Probability : 53.00 %
# Trap (105) Loading Probability : 65.00 %
# Trap (106) Loading Probability : 58.00 %
# Trap (107) Loading Probability : 53.00 %
# Trap (108) Loading Probability : 62.00 %
# Trap (109) Loading Probability : 60.00 %
# Trap (110) Loading Probability : 55.00 %
# Trap (111) Loading Probability : 54.00 %
# Trap (112) Loading Probability : 61.00 %
# Trap (113) Loading Probability : 60.00 %
# Trap (114) Loading Probability : 65.00 %
# Trap (115) Loading Probability : 60.00 %
# Trap (116) Loading Probability : 56.00 %
# Trap (117) Loading Probability : 62.00 %
# Trap (118) Loading Probability : 56.00 %
# Trap (119) Loading Probability : 64.00 %
# Trap (120) Loading Probability : 54.00 %
# Trap (121) Loading Probability : 51.00 %
# Trap (122) Loading Probability : 56.00 %
# Trap (123) Loading Probability : 58.00 %
# Trap (124) Loading Probability : 60.00 %
# Trap (125) Loading Probability : 57.00 %
# Trap (126) Loading Probability : 61.00 %
# Trap (127) Loading Probability : 65.00 %
# Trap (128) Loading Probability : 54.00 %
# Trap (129) Loading Probability : 54.00 %
# Trap (130) Loading Probability : 66.00 %
# Trap (131) Loading Probability : 62.00 %
# Trap (132) Loading Probability : 57.00 %
# Trap (133) Loading Probability : 56.00 %
# Trap (134) Loading Probability : 61.00 %
# Trap (135) Loading Probability : 65.00 %
# Trap (136) Loading Probability : 59.00 %
# Trap (137) Loading Probability : 54.00 %
# Trap (138) Loading Probability : 59.00 %
# Trap (139) Loading Probability : 57.00 %
# Trap (140) Loading Probability : 62.00 %
# Trap (141) Loading Probability : 57.00 %
# Trap (142) Loading Probability : 61.00 %
# Trap (143) Loading Probability : 56.00 %
# Trap (144) Loading Probability : 57.00 %
# Trap (145) Loading Probability : 54.00 %
# Trap (146) Loading Probability : 48.00 %
# Trap (147) Loading Probability : 52.00 %
# Trap (148) Loading Probability : 67.00 %
# Trap (149) Loading Probability : 55.00 %
# Trap (150) Loading Probability : 60.00 %
# Trap (151) Loading Probability : 63.00 %
# Trap (152) Loading Probability : 67.00 %
# Trap (153) Loading Probability : 58.00 %
# Trap (154) Loading Probability : 72.00 %
# Trap (155) Loading Probability : 56.00 %
# Trap (156) Loading Probability : 58.00 %
# Trap (157) Loading Probability : 65.00 %
# Trap (158) Loading Probability : 56.00 %
# Trap (159) Loading Probability : 64.00 %
# Trap (160) Loading Probability : 58.00 %
# Trap (161) Loading Probability : 50.00 %
# Trap (162) Loading Probability : 55.00 %
# Trap (163) Loading Probability : 56.00 %
# Trap (164) Loading Probability : 50.00 %
# Trap (165) Loading Probability : 64.00 %
# Trap (166) Loading Probability : 63.00 %
# Trap (167) Loading Probability : 58.00 %
# Trap (168) Loading Probability : 50.00 %
# Detected Loading Threshold: 51.05 photons
# Std dev of Loading Probabilities: 9.01 %
# Mean Loading Probability: 57.44 %
# Detection Fidelity: 99.29 %
# Mean Background Photon Count: 21.77 photons, Variance: 120.64 photons^2
# Mean Signal Photon Count: 108.81 photons, Variance: 607.51 photons^2
# Baseline survival probability: 0.9577

# %% [markdown]
# ### MOT Shim Coil Optimisation

# %%
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from skopt import Optimizer

# %%
# --- 1. Define the Experimental Search Space ---
dimensions = [  
    Real(name='tMOTShimXccValue', low=0.0, high=0.5),
    Real(name='tMOTShimYccValue', low=-5.0, high=0.0),
    Real(name='tMOTShimZccValue', low=-1.0, high=0.0)
]

# Experiment and camera setup
n_iterations = 20
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
hamcam.setup_acquisition("snap", n_iterations * 2)

@use_named_args(dimensions=dimensions)
def tweezer_exp_objective(tMOTShimXccValue, tMOTShimYccValue, tMOTShimZccValue):
    hamcam.start_acquisition()
    exp.start_motmaster_experiment({
            "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
            "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
            "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"), 
            "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
            "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"), 
            "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
            "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"), 
            "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
            "tMOTShimXccValue": tMOTShimXccValue, "tMOTShimYccValue": tMOTShimYccValue, "tMOTShimZccValue": tMOTShimZccValue,
            "tMolassesShimXccValue": ExpParams.get_parameter("tMolassesShimXccValue"), "tMolassesShimYccValue": ExpParams.get_parameter("tMolassesShimYccValue"), "tMolassesShimZccValue": ExpParams.get_parameter("tMolassesShimZccValue"),
            "tMOTLoadingDuration": 30000, "PatternLength": 50000})

    imgs = hamcam.acquire_n_frames(n_iterations * 2)
    imgs1, imgs2 = imgs[::2], imgs[1::2]
    imgs_filtered_1 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]

    _, loading_probabilities, _, _ = an.get_array_loading_statistics(imgs_filtered_1, grid_positions, threshold_detection=False, threshold=threshold_1, binning=60, show_histogram=False, verbose=False)    
    mean_loading_probability = np.mean(loading_probabilities)
    measured_loss = 1.0 - mean_loading_probability

    print(f"Parameters: tMOTShimXccValue = {tMOTShimXccValue:.2f}, tMOTShimYccValue = {tMOTShimYccValue:.2f}, tMOTShimZccValue = {tMOTShimZccValue:.2f}  |  Mean Loading Probability = {mean_loading_probability:.4f}")
    return measured_loss

# %%
print("Starting Bayesian Optimization with dynamic exploration...")

n_calls = 50
n_initial_points = 5
xi_start = 0.100
xi_end = 0.001

opt = Optimizer(
    dimensions=dimensions,
    n_initial_points=n_initial_points,
    acq_func='EI',
    random_state=50
)

# Custom optimization loop
for i in range(n_calls):
    current_xi = xi_start - (xi_start - xi_end) * (i / (n_calls - 1))
    opt.acq_func_kwargs = {'xi': current_xi}
    suggested_params = opt.ask()
    loss = tweezer_exp_objective(suggested_params)
    result = opt.tell(suggested_params, loss)
    print(f"Iteration {i+1}/{n_calls} (xi = {current_xi:.4f})")
    print(f"  Current score: {(1-loss):.4f}")
    print(f"  Best score: {(1-result.fun):.4f}\n")

# --- 4. Analyze the Results ---
print("\n" + "="*40)
print("Optimization Complete!")
print("="*40)

high_score = 1 - result.fun
best_params = result.x

print(f"Best Parameters Found:")
for dim, value in zip(dimensions, best_params):
    print(f"  {dim.name}: {value:.4f}")
# Out:
# Starting Bayesian Optimization with dynamic exploration...
# Parameters: tMOTShimXccValue = 0.06, tMOTShimYccValue = -4.63, tMOTShimZccValue = -0.39  |  Mean Loading Probability = 0.0615
# Iteration 1/50 (xi = 0.1000)
#   Current score: 0.0615
#   Best score: 0.0615
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -4.24, tMOTShimZccValue = -0.05  |  Mean Loading Probability = 0.3177
# Iteration 2/50 (xi = 0.0980)
#   Current score: 0.3177
#   Best score: 0.3177
#
# Parameters: tMOTShimXccValue = 0.40, tMOTShimYccValue = -3.78, tMOTShimZccValue = -0.67  |  Mean Loading Probability = 0.0094
# Iteration 3/50 (xi = 0.0960)
#   Current score: 0.0094
#   Best score: 0.3177
#
# Parameters: tMOTShimXccValue = 0.22, tMOTShimYccValue = -4.33, tMOTShimZccValue = -0.41  |  Mean Loading Probability = 0.0618
# Iteration 4/50 (xi = 0.0939)
#   Current score: 0.0618
#   Best score: 0.3177
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -4.56, tMOTShimZccValue = -0.71  |  Mean Loading Probability = 0.0056
# Iteration 5/50 (xi = 0.0919)
#   Current score: 0.0056
#   Best score: 0.3177
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -0.91, tMOTShimZccValue = 0.00  |  Mean Loading Probability = 0.4399
# Iteration 6/50 (xi = 0.0899)
#   Current score: 0.4399
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.17, tMOTShimYccValue = -0.07, tMOTShimZccValue = -1.00  |  Mean Loading Probability = 0.0028
# Iteration 7/50 (xi = 0.0879)
#   Current score: 0.0028
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.06, tMOTShimYccValue = -0.02, tMOTShimZccValue = -0.13  |  Mean Loading Probability = 0.3438
# Iteration 8/50 (xi = 0.0859)
#   Current score: 0.3438
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -0.18, tMOTShimZccValue = -0.00  |  Mean Loading Probability = 0.3139
# Iteration 9/50 (xi = 0.0838)
#   Current score: 0.3139
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = 0.00, tMOTShimZccValue = -0.12  |  Mean Loading Probability = 0.3590
# Iteration 10/50 (xi = 0.0818)
#   Current score: 0.3590
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -4.71, tMOTShimZccValue = -0.81  |  Mean Loading Probability = 0.0347
# Iteration 11/50 (xi = 0.0798)
#   Current score: 0.0347
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.32, tMOTShimYccValue = -4.90, tMOTShimZccValue = -0.01  |  Mean Loading Probability = 0.2597
# Iteration 12/50 (xi = 0.0778)
#   Current score: 0.2597
#   Best score: 0.4399
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -2.18, tMOTShimZccValue = 0.00  |  Mean Loading Probability = 0.4778
# Iteration 13/50 (xi = 0.0758)
#   Current score: 0.4778
#   Best score: 0.4778
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -1.63, tMOTShimZccValue = -0.17  |  Mean Loading Probability = 0.5146
# Iteration 14/50 (xi = 0.0737)
#   Current score: 0.5146
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -0.79, tMOTShimZccValue = -0.40  |  Mean Loading Probability = 0.2399
# Iteration 15/50 (xi = 0.0717)
#   Current score: 0.2399
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -2.34, tMOTShimZccValue = -0.13  |  Mean Loading Probability = 0.5063
# Iteration 16/50 (xi = 0.0697)
#   Current score: 0.5063
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -1.66, tMOTShimZccValue = -0.07  |  Mean Loading Probability = 0.5111
# Iteration 17/50 (xi = 0.0677)
#   Current score: 0.5111
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.47, tMOTShimYccValue = -3.06, tMOTShimZccValue = -1.00  |  Mean Loading Probability = 0.0403
# Iteration 18/50 (xi = 0.0657)
#   Current score: 0.0403
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.10, tMOTShimYccValue = -0.01, tMOTShimZccValue = -0.68  |  Mean Loading Probability = 0.0139
# Iteration 19/50 (xi = 0.0636)
#   Current score: 0.0139
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.48, tMOTShimYccValue = -2.03, tMOTShimZccValue = -0.10  |  Mean Loading Probability = 0.5146
# Iteration 20/50 (xi = 0.0616)
#   Current score: 0.5146
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.00, tMOTShimYccValue = -2.03, tMOTShimZccValue = -0.25  |  Mean Loading Probability = 0.4868
# Iteration 21/50 (xi = 0.0596)
#   Current score: 0.4868
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.67, tMOTShimZccValue = -0.22  |  Mean Loading Probability = 0.5080
# Iteration 22/50 (xi = 0.0576)
#   Current score: 0.5080
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -3.09, tMOTShimZccValue = -0.10  |  Mean Loading Probability = 0.4635
# Iteration 23/50 (xi = 0.0556)
#   Current score: 0.4635
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -4.98, tMOTShimZccValue = -1.00  |  Mean Loading Probability = 0.0063
# Iteration 24/50 (xi = 0.0535)
#   Current score: 0.0062
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.00, tMOTShimYccValue = -3.48, tMOTShimZccValue = -0.21  |  Mean Loading Probability = 0.4243
# Iteration 25/50 (xi = 0.0515)
#   Current score: 0.4243
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.47, tMOTShimYccValue = -0.00, tMOTShimZccValue = -0.28  |  Mean Loading Probability = 0.4288
# Iteration 26/50 (xi = 0.0495)
#   Current score: 0.4288
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.47, tMOTShimYccValue = -1.05, tMOTShimZccValue = -0.24  |  Mean Loading Probability = 0.4830
# Iteration 27/50 (xi = 0.0475)
#   Current score: 0.4830
#   Best score: 0.5146
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.25, tMOTShimZccValue = -0.18  |  Mean Loading Probability = 0.5274
# Iteration 28/50 (xi = 0.0454)
#   Current score: 0.5274
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.46, tMOTShimYccValue = -4.97, tMOTShimZccValue = -0.17  |  Mean Loading Probability = 0.2316
# Iteration 29/50 (xi = 0.0434)
#   Current score: 0.2316
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.40, tMOTShimYccValue = -1.60, tMOTShimZccValue = -0.83  |  Mean Loading Probability = 0.0441
# Iteration 30/50 (xi = 0.0414)
#   Current score: 0.0441
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.29, tMOTShimZccValue = -0.30  |  Mean Loading Probability = 0.4097
# Iteration 31/50 (xi = 0.0394)
#   Current score: 0.4097
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -1.24, tMOTShimZccValue = -0.09  |  Mean Loading Probability = 0.4969
# Iteration 32/50 (xi = 0.0374)
#   Current score: 0.4969
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.00, tMOTShimYccValue = -3.31, tMOTShimZccValue = -0.00  |  Mean Loading Probability = 0.3448
# Iteration 33/50 (xi = 0.0353)
#   Current score: 0.3448
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.32, tMOTShimYccValue = -0.01, tMOTShimZccValue = -0.51  |  Mean Loading Probability = 0.0618
# Iteration 34/50 (xi = 0.0333)
#   Current score: 0.0618
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.46, tMOTShimYccValue = -1.63, tMOTShimZccValue = -0.03  |  Mean Loading Probability = 0.4840
# Iteration 35/50 (xi = 0.0313)
#   Current score: 0.4840
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.48, tMOTShimYccValue = -2.09, tMOTShimZccValue = -0.18  |  Mean Loading Probability = 0.5243
# Iteration 36/50 (xi = 0.0293)
#   Current score: 0.5243
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.03, tMOTShimYccValue = -1.47, tMOTShimZccValue = -0.16  |  Mean Loading Probability = 0.4882
# Iteration 37/50 (xi = 0.0273)
#   Current score: 0.4882
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.48, tMOTShimYccValue = -2.48, tMOTShimZccValue = -0.16  |  Mean Loading Probability = 0.5153
# Iteration 38/50 (xi = 0.0252)
#   Current score: 0.5153
#   Best score: 0.5274
#
# Parameters: tMOTShimXccValue = 0.47, tMOTShimYccValue = -1.98, tMOTShimZccValue = -0.12  |  Mean Loading Probability = 0.5292
# Iteration 39/50 (xi = 0.0232)
#   Current score: 0.5292
#   Best score: 0.5292
#
# Parameters: tMOTShimXccValue = 0.46, tMOTShimYccValue = -1.81, tMOTShimZccValue = -0.20  |  Mean Loading Probability = 0.5056
# Iteration 40/50 (xi = 0.0212)
#   Current score: 0.5056
#   Best score: 0.5292
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -1.86, tMOTShimZccValue = -0.09  |  Mean Loading Probability = 0.5333
# Iteration 41/50 (xi = 0.0192)
#   Current score: 0.5333
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.05, tMOTShimZccValue = -0.11  |  Mean Loading Probability = 0.5101
# Iteration 42/50 (xi = 0.0172)
#   Current score: 0.5101
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.01, tMOTShimYccValue = -2.42, tMOTShimZccValue = -0.18  |  Mean Loading Probability = 0.5122
# Iteration 43/50 (xi = 0.0151)
#   Current score: 0.5122
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -2.23, tMOTShimZccValue = -0.06  |  Mean Loading Probability = 0.5208
# Iteration 44/50 (xi = 0.0131)
#   Current score: 0.5208
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -2.32, tMOTShimZccValue = -0.16  |  Mean Loading Probability = 0.5312
# Iteration 45/50 (xi = 0.0111)
#   Current score: 0.5312
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -1.87, tMOTShimZccValue = -0.10  |  Mean Loading Probability = 0.5243
# Iteration 46/50 (xi = 0.0091)
#   Current score: 0.5243
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.51, tMOTShimZccValue = -0.16  |  Mean Loading Probability = 0.5219
# Iteration 47/50 (xi = 0.0071)
#   Current score: 0.5219
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -2.04, tMOTShimZccValue = -0.15  |  Mean Loading Probability = 0.5038
# Iteration 48/50 (xi = 0.0050)
#   Current score: 0.5038
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.50, tMOTShimYccValue = -1.97, tMOTShimZccValue = -0.07  |  Mean Loading Probability = 0.5132
# Iteration 49/50 (xi = 0.0030)
#   Current score: 0.5132
#   Best score: 0.5333
#
# Parameters: tMOTShimXccValue = 0.49, tMOTShimYccValue = -2.07, tMOTShimZccValue = -0.21  |  Mean Loading Probability = 0.5069
# Iteration 50/50 (xi = 0.0010)
#   Current score: 0.5069
#   Best score: 0.5333
#
#
# ========================================
# Optimization Complete!
# ========================================
# Best Parameters Found:
#   tMOTShimXccValue: 0.4991
#   tMOTShimYccValue: -1.8649
#   tMOTShimZccValue: -0.0872

# %%
ExpParams.set_parameter("tMOTShimXccValue", best_params[0])
ExpParams.set_parameter("tMOTShimYccValue", best_params[1])
ExpParams.set_parameter("tMOTShimZccValue", best_params[2])
ExpParams.save_parameters()
# Out:
# Parameter 'tMOTShimXccValue' set to 0.4991451750157772.
# Parameter 'tMOTShimYccValue' set to -1.8648591545365227.
# Parameter 'tMOTShimZccValue' set to -0.08719931424260197.
# Parameters saved.

# %% [markdown]
# ### Molasses Shim Coil Optimisation

# %%
# --- 1. Define the Experimental Search Space ---
dimensions = [  
    Real(name='tMolassesShimXccValue', low=5.0, high=10.0), 
    Real(name='tMolassesShimYccValue', low=0.0, high=5.0), 
    Real(name='tMolassesShimZccValue', low=0.0, high=1.0)
]

# Experiment and camera setup
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
hamcam.setup_acquisition("snap", n_iterations * 2)

@use_named_args(dimensions=dimensions)
def tweezer_exp_objective(tMolassesShimXccValue, tMolassesShimYccValue, tMolassesShimZccValue):
    # Check loading probability
    n_iterations = 20
    exp.set_motmaster_experiment("RbTweezerBasic2026_2")
    exp.set_iterations(n_iterations)
    hamcam.setup_acquisition("snap", n_iterations * 2)
    hamcam.start_acquisition()
    exp.start_motmaster_experiment({
        "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
        "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
        "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"),
        "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
        "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"),
        "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
        "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"),
        "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
        "tMOTShimXccValue": ExpParams.get_parameter("tMOTShimXccValue"), "tMOTShimYccValue": ExpParams.get_parameter("tMOTShimYccValue"), "tMOTShimZccValue": ExpParams.get_parameter("tMOTShimZccValue"),
        "tMolassesShimXccValue": tMolassesShimXccValue, "tMolassesShimYccValue": tMolassesShimYccValue, "tMolassesShimZccValue": tMolassesShimZccValue, 
        "BackgroundDrop": 1, "tDropDuration": int(4)})
    imgs = hamcam.acquire_n_frames(n_iterations * 2)
    imgs1, imgs2 = imgs[::2], imgs[1::2]
    imgs_filtered_1 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]
    imgs_filtered_2 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs2]
    _, loading_probabilities, threshold, _ = an.get_array_loading_statistics(imgs_filtered_1, grid_positions, threshold_detection=False, threshold=threshold_1, binning=60, show_histogram=False, verbose=False)

    mean_loading_probability = loading_probabilities.mean()

    if mean_loading_probability < 0.5:
        measured_loss = 1 - mean_loading_probability
        survival_probability = np.nan
    else:
        survival_probability = an.extract_survival_probability(imgs_filtered_1, imgs_filtered_2, grid_positions, threshold=threshold, window_size=window)
        measured_loss = 0.4 - survival_probability

    print(f"tMolassesShimXccValue = {tMolassesShimXccValue:.2f}, tMolassesShimYccValue = {tMolassesShimYccValue:.2f}, tMolassesShimZccValue = {tMolassesShimZccValue:.2f}  |  Loading Probability = {mean_loading_probability:.4f}  |  40 us Survival Probability = {survival_probability:.4f}")
    
    return measured_loss

# %%
print("Starting Bayesian Optimization with dynamic exploration...")

n_calls = 50
n_initial_points = 10
xi_start = 0.100
xi_end = 0.001

opt = Optimizer(
    dimensions=dimensions,
    n_initial_points=n_initial_points,
    acq_func='EI',
    random_state=50
)

# Custom optimization loop
for i in range(n_calls):
    current_xi = xi_start - (xi_start - xi_end) * (i / (n_calls - 1))
    opt.acq_func_kwargs = {'xi': current_xi}
    suggested_params = opt.ask()
    loss = tweezer_exp_objective(suggested_params)
    result = opt.tell(suggested_params, loss)
    print(f"Iteration {i+1}/{n_calls} (xi = {current_xi:.4f})")
    print(f"  Current score: {(loss):.4f}")
    print(f"  Best score: {(result.fun):.4f}\n")

# --- 4. Analyze the Results ---
print("\n" + "="*40)
print("Optimization Complete!")
print("="*40)

high_score = 1 - result.fun
best_params = result.x

print(f"Best Parameters Found:")
for dim, value in zip(dimensions, best_params):
    print(f"  {dim.name}: {value:.4f}")
# Out:
# Starting Bayesian Optimization with dynamic exploration...
# tMolassesShimXccValue = 5.65, tMolassesShimYccValue = 0.37, tMolassesShimZccValue = 0.61  |  Loading Probability = 0.0007  |  40 us Survival Probability = nan
# Iteration 1/50 (xi = 0.1000)
#   Current score: 0.9993
#   Best score: 0.9993
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:741: RuntimeWarning: Mean of empty slice
#   mu_sig = tot_photon_array[tot_photon_array >= threshold].mean()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:743: RuntimeWarning: Degrees of freedom <= 0 for slice
#   var_sig = tot_photon_array[tot_photon_array >= threshold].var()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# tMolassesShimXccValue = 5.11, tMolassesShimYccValue = 0.76, tMolassesShimZccValue = 0.95  |  Loading Probability = 0.0000  |  40 us Survival Probability = nan
# Iteration 2/50 (xi = 0.0980)
#   Current score: 1.0000
#   Best score: 0.9993
#
# tMolassesShimXccValue = 9.02, tMolassesShimYccValue = 1.22, tMolassesShimZccValue = 0.33  |  Loading Probability = 0.2762  |  40 us Survival Probability = nan
# Iteration 3/50 (xi = 0.0960)
#   Current score: 0.7238
#   Best score: 0.7238
#
# tMolassesShimXccValue = 7.20, tMolassesShimYccValue = 0.67, tMolassesShimZccValue = 0.59  |  Loading Probability = 0.0011  |  40 us Survival Probability = nan
# Iteration 4/50 (xi = 0.0939)
#   Current score: 0.9989
#   Best score: 0.7238
#
# tMolassesShimXccValue = 9.89, tMolassesShimYccValue = 0.44, tMolassesShimZccValue = 0.29  |  Loading Probability = 0.1709  |  40 us Survival Probability = nan
# Iteration 5/50 (xi = 0.0919)
#   Current score: 0.8291
#   Best score: 0.7238
#
# tMolassesShimXccValue = 6.20, tMolassesShimYccValue = 2.58, tMolassesShimZccValue = 0.05  |  Loading Probability = 0.5089  |  40 us Survival Probability = 0.2555
# Iteration 6/50 (xi = 0.0899)
#   Current score: 0.1445
#   Best score: 0.1445
#
# tMolassesShimXccValue = 6.32, tMolassesShimYccValue = 3.36, tMolassesShimZccValue = 0.79  |  Loading Probability = 0.0000  |  40 us Survival Probability = nan
# Iteration 7/50 (xi = 0.0879)
#   Current score: 1.0000
#   Best score: 0.1445
#
# tMolassesShimXccValue = 6.82, tMolassesShimYccValue = 0.57, tMolassesShimZccValue = 0.17  |  Loading Probability = 0.3860  |  40 us Survival Probability = nan
# Iteration 8/50 (xi = 0.0859)
#   Current score: 0.6140
#   Best score: 0.1445
#
# tMolassesShimXccValue = 5.09, tMolassesShimYccValue = 3.94, tMolassesShimZccValue = 0.28  |  Loading Probability = 0.5078  |  40 us Survival Probability = 0.2303
# Iteration 9/50 (xi = 0.0838)
#   Current score: 0.1697
#   Best score: 0.1445
#
# tMolassesShimXccValue = 9.33, tMolassesShimYccValue = 2.64, tMolassesShimZccValue = 0.69  |  Loading Probability = 0.0000  |  40 us Survival Probability = nan
# Iteration 10/50 (xi = 0.0818)
#   Current score: 1.0000
#   Best score: 0.1445
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.5284  |  40 us Survival Probability = 0.2495
# Iteration 11/50 (xi = 0.0798)
#   Current score: 0.1505
#   Best score: 0.1445
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 4.04, tMolassesShimZccValue = 0.11  |  Loading Probability = 0.5304  |  40 us Survival Probability = 0.2892
# Iteration 12/50 (xi = 0.0778)
#   Current score: 0.1108
#   Best score: 0.1108
#
# tMolassesShimXccValue = 10.00, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.22  |  Loading Probability = 0.3364  |  40 us Survival Probability = nan
# Iteration 13/50 (xi = 0.0758)
#   Current score: 0.6636
#   Best score: 0.1108
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 3.08, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.5171  |  40 us Survival Probability = 0.2364
# Iteration 14/50 (xi = 0.0737)
#   Current score: 0.1636
#   Best score: 0.1108
#
# tMolassesShimXccValue = 6.72, tMolassesShimYccValue = 3.90, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.5167  |  40 us Survival Probability = 0.2710
# Iteration 15/50 (xi = 0.0717)
#   Current score: 0.1290
#   Best score: 0.1108
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.22  |  Loading Probability = 0.5198  |  40 us Survival Probability = 0.2409
# Iteration 16/50 (xi = 0.0697)
#   Current score: 0.1591
#   Best score: 0.1108
#
# tMolassesShimXccValue = 6.28, tMolassesShimYccValue = 3.83, tMolassesShimZccValue = 0.15  |  Loading Probability = 0.6593  |  40 us Survival Probability = 0.2742
# Iteration 17/50 (xi = 0.0677)
#   Current score: 0.1258
#   Best score: 0.1108
#
# tMolassesShimXccValue = 8.56, tMolassesShimYccValue = 2.67, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.3807  |  40 us Survival Probability = nan
# Iteration 18/50 (xi = 0.0657)
#   Current score: 0.6193
#   Best score: 0.1108
#
# tMolassesShimXccValue = 5.86, tMolassesShimYccValue = 4.00, tMolassesShimZccValue = 0.01  |  Loading Probability = 0.5227  |  40 us Survival Probability = 0.2716
# Iteration 19/50 (xi = 0.0636)
#   Current score: 0.1284
#   Best score: 0.1108
#
# tMolassesShimXccValue = 6.29, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.09  |  Loading Probability = 0.5480  |  40 us Survival Probability = 0.2698
# Iteration 20/50 (xi = 0.0616)
#   Current score: 0.1302
#   Best score: 0.1108
#
# tMolassesShimXccValue = 5.66, tMolassesShimYccValue = 3.71, tMolassesShimZccValue = 0.11  |  Loading Probability = 0.5420  |  40 us Survival Probability = 0.2915
# Iteration 21/50 (xi = 0.0596)
#   Current score: 0.1085
#   Best score: 0.1085
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 0.00, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.2071  |  40 us Survival Probability = nan
# Iteration 22/50 (xi = 0.0576)
#   Current score: 0.7929
#   Best score: 0.1085
#
# tMolassesShimXccValue = 7.34, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.00  |  Loading Probability = 0.5142  |  40 us Survival Probability = 0.2304
# Iteration 23/50 (xi = 0.0556)
#   Current score: 0.1696
#   Best score: 0.1085
#
# tMolassesShimXccValue = 5.00, tMolassesShimYccValue = 2.78, tMolassesShimZccValue = 0.18  |  Loading Probability = 0.5318  |  40 us Survival Probability = 0.2592
# Iteration 24/50 (xi = 0.0535)
#   Current score: 0.1408
#   Best score: 0.1085
#
# tMolassesShimXccValue = 7.32, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 0.26  |  Loading Probability = 0.4818  |  40 us Survival Probability = nan
# Iteration 25/50 (xi = 0.0515)
#   Current score: 0.5182
#   Best score: 0.1085
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:741: RuntimeWarning: Mean of empty slice
#   mu_sig = tot_photon_array[tot_photon_array >= threshold].mean()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:743: RuntimeWarning: Degrees of freedom <= 0 for slice
#   var_sig = tot_photon_array[tot_photon_array >= threshold].var()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# tMolassesShimXccValue = 10.00, tMolassesShimYccValue = 0.00, tMolassesShimZccValue = 1.00  |  Loading Probability = 0.0000  |  40 us Survival Probability = nan
# Iteration 26/50 (xi = 0.0495)
#   Current score: 1.0000
#   Best score: 0.1085
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:741: RuntimeWarning: Mean of empty slice
#   mu_sig = tot_photon_array[tot_photon_array >= threshold].mean()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\tweez\ColdMatter\pytweezer\pytweezer\analysis.py:743: RuntimeWarning: Degrees of freedom <= 0 for slice
#   var_sig = tot_photon_array[tot_photon_array >= threshold].var()
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# tMolassesShimXccValue = 10.00, tMolassesShimYccValue = 5.00, tMolassesShimZccValue = 1.00  |  Loading Probability = 0.0000  |  40 us Survival Probability = nan
# Iteration 27/50 (xi = 0.0475)
#   Current score: 1.0000
#   Best score: 0.1085
#
# tMolassesShimXccValue = 6.07, tMolassesShimYccValue = 2.84, tMolassesShimZccValue = 0.18  |  Loading Probability = 0.5644  |  40 us Survival Probability = 0.2412
# Iteration 28/50 (xi = 0.0454)
#   Current score: 0.1588
#   Best score: 0.1085
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[168], line 20
#      18 opt.acq_func_kwargs = {'xi': current_xi}
#      19 suggested_params = opt.ask()
# ---> 20 loss = tweezer_exp_objective(suggested_params)
#      21 result = opt.tell(suggested_params, loss)
#      22 print(f"Iteration {i+1}/{n_calls} (xi = {current_xi:.4f})")
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\skopt\utils.py:779, in use_named_args.<locals>.decorator.<locals>.wrapper(x)
#     776 arg_dict = {dim.name: value for dim, value in zip(dimensions, x)}
#     778 # Call the wrapped objective function with the named arguments.
# --> 779 objective_value = func(**arg_dict)
#     781 return objective_value
#
# Cell In[167], line 33, in tweezer_exp_objective(tMolassesShimXccValue, tMolassesShimYccValue, tMolassesShimZccValue)
#      20 hamcam.start_acquisition()
#      21 exp.start_motmaster_experiment({
#      22     "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
#      23     "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
#    (...)     31     "tMolassesShimXccValue": tMolassesShimXccValue, "tMolassesShimYccValue": tMolassesShimYccValue, "tMolassesShimZccValue": tMolassesShimZccValue,
#      32     "BackgroundDrop": 1, "tDropDuration": int(4)})
# ---> 33 imgs = hamcam.acquire_n_frames(n_iterations * 2)
#      34 imgs1, imgs2 = imgs[::2], imgs[1::2]
#      35 imgs_filtered_1 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]
#
# File ~\ColdMatter\pytweezer\pytweezer\drivers\imagemX2.py:20, in requires_camera.<locals>.wrapper(self, *args, **kwargs)
#      17 @wraps(func)
#      18 def wrapper(self, *args, **kwargs):
#      19     self._require_camera()
# ---> 20     return func(self, *args, **kwargs)
#
# File ~\ColdMatter\pytweezer\pytweezer\drivers\imagemX2.py:122, in ImagEMX2Camera.acquire_n_frames(self, nframes, start_frame, autosave, broadcast)
#     120 @requires_camera
#     121 def acquire_n_frames(self, nframes: int, start_frame: int = 0, autosave: bool = False, broadcast: bool = False) -> np.ndarray:
# --> 122     self.dcam.wait_for_frame(nframes=int(nframes), timeout=self.timeout)
#     123     images, _infos = self.dcam.read_multiple_images(
#     124         (int(start_frame), int(start_frame) + int(nframes)), return_info=True
#     125     )
#     126     for i, image in enumerate(images):
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\pylablib\core\devio\interface.py:666, in use_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     663 @functools.wraps(func)
#     664 def wrapped(*args, **kwargs):
#     665     all_args=parse_args(args,kwargs)
# --> 666     res=func(**all_args)
#     667     return parse_reply(res,args,kwargs)
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\pylablib\devices\interface\camera.py:263, in ICamera.wait_for_frame(self, since, nframes, timeout, error_on_stopped)
#     261     if to is not None and to<=0:
#     262         raise self.TimeoutError
# --> 263     self._wait_for_next_frame(timeout=to,idx=acquired_frames)
#     264 self._frame_counter.wait_done()
#     265 return True
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\pylablib\devices\DCAM\DCAM.py:507, in DCAMCamera._wait_for_next_frame(self, timeout, idx)
#     505 try:
#     506     eventmask=dcamapi4_lib.DCAMWAIT_EVENT.DCAMWAIT_CAPEVENT_FRAMEREADY
# --> 507     lib.dcamwait_start(self.dcamwait.hwait,eventmask,int(timeout*1000))
#     508     return
#     509 except DCAMLibError as e:
#
# File <string>:1, in <lambda>(hWait, eventmask, timeout)
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File c:\Users\tweez\AppData\Local\pypoetry\Cache\virtualenvs\pytweezer-E_bIt_dZ-py3.11\Lib\site-packages\pylablib\devices\DCAM\dcamapi4_lib.py:38, in errcheck.<locals>.errchecker(result, func, arguments)
#      31 """
#      32 Build an error checking function.
#      33
#      34 Return a function which checks return codes of DCAM library functions.
#      35 `passing` is a list specifying which return codes are acceptable (by default, non-negative codes are acceptable).
#      36 """
#      37 passing=set(passing) if passing is not None else set()
# ---> 38 def errchecker(result, func, arguments):  # pylint: disable=unused-argument
#      39     if isinstance(result,tuple):
#      40         code,result=result[0],result[1:]
#
# KeyboardInterrupt:

# %%
for dim, value in zip(dimensions, best_params):
    print(f"  {dim.name}: {value:.4f}")
    ExpParams.set_parameter(dim.name, value)
ExpParams.save_parameters()
# Out:
#   tMolassesShimXccValue: 5.6100
# Parameter 'tMolassesShimXccValue' set to 5.609956063783662.
#   tMolassesShimYccValue: 4.4659
# Parameter 'tMolassesShimYccValue' set to 4.465918604815521.
#   tMolassesShimZccValue: 0.1365
# Parameter 'tMolassesShimZccValue' set to 0.13646836204370819.
# Parameters saved.

# %% [markdown]
# ### Imaging VCO Scan

# %%
# Experiment and camera setup
n_iterations = 20
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
hamcam.setup_acquisition("snap", n_iterations * 2)

vco_list = np.linspace(1.0, 3.0, 30)
surv_list, loading_list, fidelity_list = [], [], []

for vco in vco_list:
    ExpParams.set_parameter("tImgCoolVCO", vco)
    hamcam.start_acquisition()
    exp.start_motmaster_experiment({
        "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
        "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
        "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"), 
        "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
        "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"), 
        "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
        "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"), 
        "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
        "tMOTShimXccValue": ExpParams.get_parameter("tMOTShimXccValue"), "tMOTShimYccValue": ExpParams.get_parameter("tMOTShimYccValue"), "tMOTShimZccValue": ExpParams.get_parameter("tMOTShimZccValue"),
        "tMolassesShimXccValue": ExpParams.get_parameter("tMolassesShimXccValue"), "tMolassesShimYccValue": ExpParams.get_parameter("tMolassesShimYccValue"), "tMolassesShimZccValue": ExpParams.get_parameter("tMolassesShimZccValue"),
        "BackgroundDrop": 0})

    imgs = hamcam.acquire_n_frames(n_iterations * 2)
    imgs1, imgs2 = imgs[::2], imgs[1::2]
    imgs_filtered_1 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs1]
    imgs_filtered_2 = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs2]
    photon_rates, loading_probabilities, threshold, fidelity = an.get_array_loading_statistics(imgs_filtered_1, grid_positions, threshold_detection=True, window_size=window, binning=60, verbose=False, show_histogram=False)
    survival_probability = an.extract_survival_probability(imgs_filtered_1, imgs_filtered_2, grid_positions, window_size=window)
    mean_loading_probability = np.mean(loading_probabilities)

    surv_list.append(survival_probability)
    loading_list.append(mean_loading_probability)
    fidelity_list.append(fidelity)

    print(f"Cooling VCO: {vco:.3f} V, Mean Loading Probability: {mean_loading_probability*100:.4f} %, Survival Probability: {survival_probability*100:.4f} %, Detection Fidelity: {fidelity*100:.4f} %")
# Out:
# Parameter 'tImgCoolVCO' set to 1.0.
# Cooling VCO: 1.000 V, Mean Loading Probability: 56.8667 %, Survival Probability: 96.2144 %, Detection Fidelity: 98.9785 %
# Parameter 'tImgCoolVCO' set to 1.0689655172413792.
# Cooling VCO: 1.069 V, Mean Loading Probability: 55.3778 %, Survival Probability: 96.6843 %, Detection Fidelity: 99.2334 %
# Parameter 'tImgCoolVCO' set to 1.1379310344827587.
# Cooling VCO: 1.138 V, Mean Loading Probability: 56.6444 %, Survival Probability: 96.1448 %, Detection Fidelity: 99.2705 %
# Parameter 'tImgCoolVCO' set to 1.206896551724138.
# Cooling VCO: 1.207 V, Mean Loading Probability: 55.4444 %, Survival Probability: 97.2029 %, Detection Fidelity: 99.5012 %
# Parameter 'tImgCoolVCO' set to 1.2758620689655173.
# Cooling VCO: 1.276 V, Mean Loading Probability: 55.1333 %, Survival Probability: 97.3835 %, Detection Fidelity: 99.5550 %
# Parameter 'tImgCoolVCO' set to 1.3448275862068966.
# Cooling VCO: 1.345 V, Mean Loading Probability: 54.9556 %, Survival Probability: 97.4331 %, Detection Fidelity: 99.5205 %
# Parameter 'tImgCoolVCO' set to 1.4137931034482758.
# Cooling VCO: 1.414 V, Mean Loading Probability: 54.6000 %, Survival Probability: 96.4119 %, Detection Fidelity: 99.6676 %
# Parameter 'tImgCoolVCO' set to 1.4827586206896552.
# Cooling VCO: 1.483 V, Mean Loading Probability: 53.8222 %, Survival Probability: 97.7119 %, Detection Fidelity: 99.6644 %
# Parameter 'tImgCoolVCO' set to 1.5517241379310345.
# Cooling VCO: 1.552 V, Mean Loading Probability: 54.8000 %, Survival Probability: 96.5194 %, Detection Fidelity: 99.7181 %
# Parameter 'tImgCoolVCO' set to 1.6206896551724137.
# Cooling VCO: 1.621 V, Mean Loading Probability: 55.4667 %, Survival Probability: 96.7358 %, Detection Fidelity: 99.7124 %
# Parameter 'tImgCoolVCO' set to 1.6896551724137931.
# Cooling VCO: 1.690 V, Mean Loading Probability: 54.8889 %, Survival Probability: 96.5971 %, Detection Fidelity: 99.7646 %
# Parameter 'tImgCoolVCO' set to 1.7586206896551724.
# Cooling VCO: 1.759 V, Mean Loading Probability: 54.4444 %, Survival Probability: 97.2745 %, Detection Fidelity: 99.8738 %
# Parameter 'tImgCoolVCO' set to 1.8275862068965516.
# Cooling VCO: 1.828 V, Mean Loading Probability: 54.8889 %, Survival Probability: 97.3794 %, Detection Fidelity: 99.8423 %
# Parameter 'tImgCoolVCO' set to 1.896551724137931.
# Cooling VCO: 1.897 V, Mean Loading Probability: 55.8444 %, Survival Probability: 97.0256 %, Detection Fidelity: 99.8857 %
# Parameter 'tImgCoolVCO' set to 1.9655172413793103.
# Cooling VCO: 1.966 V, Mean Loading Probability: 54.7778 %, Survival Probability: 96.3590 %, Detection Fidelity: 99.8851 %
# Parameter 'tImgCoolVCO' set to 2.0344827586206895.
# Cooling VCO: 2.034 V, Mean Loading Probability: 55.0667 %, Survival Probability: 96.4772 %, Detection Fidelity: 99.8920 %
# Parameter 'tImgCoolVCO' set to 2.103448275862069.
# Cooling VCO: 2.103 V, Mean Loading Probability: 56.3111 %, Survival Probability: 96.3355 %, Detection Fidelity: 99.8966 %
# Parameter 'tImgCoolVCO' set to 2.1724137931034484.
# Cooling VCO: 2.172 V, Mean Loading Probability: 55.0444 %, Survival Probability: 94.2495 %, Detection Fidelity: 99.9025 %
# Parameter 'tImgCoolVCO' set to 2.2413793103448274.
# Cooling VCO: 2.241 V, Mean Loading Probability: 55.0667 %, Survival Probability: 94.2322 %, Detection Fidelity: 99.8973 %
# Parameter 'tImgCoolVCO' set to 2.310344827586207.
# Cooling VCO: 2.310 V, Mean Loading Probability: 54.7556 %, Survival Probability: 93.4082 %, Detection Fidelity: 99.9235 %
# Parameter 'tImgCoolVCO' set to 2.3793103448275863.
# Cooling VCO: 2.379 V, Mean Loading Probability: 54.2000 %, Survival Probability: 92.2243 %, Detection Fidelity: 99.8892 %
# Parameter 'tImgCoolVCO' set to 2.4482758620689653.
# Cooling VCO: 2.448 V, Mean Loading Probability: 54.5778 %, Survival Probability: 89.6721 %, Detection Fidelity: 99.8968 %
# Parameter 'tImgCoolVCO' set to 2.5172413793103448.
# Cooling VCO: 2.517 V, Mean Loading Probability: 54.8222 %, Survival Probability: 90.0244 %, Detection Fidelity: 99.8744 %
# Parameter 'tImgCoolVCO' set to 2.586206896551724.
# Cooling VCO: 2.586 V, Mean Loading Probability: 55.7556 %, Survival Probability: 86.1497 %, Detection Fidelity: 99.7896 %
# Parameter 'tImgCoolVCO' set to 2.655172413793103.
# Cooling VCO: 2.655 V, Mean Loading Probability: 53.0667 %, Survival Probability: 83.5250 %, Detection Fidelity: 99.7390 %
# Parameter 'tImgCoolVCO' set to 2.7241379310344827.
# Cooling VCO: 2.724 V, Mean Loading Probability: 54.0000 %, Survival Probability: 81.8819 %, Detection Fidelity: 99.6925 %
# Parameter 'tImgCoolVCO' set to 2.793103448275862.
# Cooling VCO: 2.793 V, Mean Loading Probability: 53.2889 %, Survival Probability: 79.9178 %, Detection Fidelity: 99.5805 %
# Parameter 'tImgCoolVCO' set to 2.862068965517241.
# Cooling VCO: 2.862 V, Mean Loading Probability: 52.1111 %, Survival Probability: 72.9774 %, Detection Fidelity: 99.0659 %
# Parameter 'tImgCoolVCO' set to 2.9310344827586206.
# Cooling VCO: 2.931 V, Mean Loading Probability: 56.5556 %, Survival Probability: 73.1297 %, Detection Fidelity: 99.0745 %
# Parameter 'tImgCoolVCO' set to 3.0.
# Cooling VCO: 3.000 V, Mean Loading Probability: 54.4889 %, Survival Probability: 63.1000 %, Detection Fidelity: 98.1294 %

# %%
# Plot the loading probability vs vco in one plot and in a second plot plot the survival probability and detection fidelity vs vco in the same plot with different y axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.scatter(vco_list, loading_list, label="Loading Probability", color="blue")
ax1.set_xlabel("VCO")
ax1.set_ylabel("Loading Probability")
ax1.set_title("Optimisation Scan")
ax1.legend()

# Create a second y-axis for the right plot
ax2_right = ax2.twinx()
ax2.scatter(vco_list, surv_list, label="Survival Probability", color="blue")
ax2_right.scatter(vco_list, fidelity_list, label="Detection Fidelity", color="green")

# Set labels and titles
ax2.set_xlabel("VCO")
ax2.set_ylabel("Survival Probability")
ax2_right.set_ylabel("Detection Fidelity")
ax2.set_title("Optimisation Scan")

# Combine legends
lines1, labels1 = ax2.get_legend_handles_labels()
lines2, labels2 = ax2_right.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2)

max_index = np.argmax(surv_list)

print(f"Optimal Cooling VCO: {vco_list[max_index]:.3f} V, Survival Probability: {surv_list[max_index]*100:.4f} %, Loading Probability: {loading_list[max_index]*100:.4f} %, Detection Fidelity: {fidelity_list[max_index]*100:.4f} %")
# Out:
# Optimal Cooling VCO: 1.483 V, Survival Probability: 97.7119 %, Loading Probability: 53.8222 %, Detection Fidelity: 99.6644 %

# %%
ExpParams.set_parameter("tImgCoolVCO", 1.6)
# Out:
# Parameter 'tImgCoolVCO' set to 1.6.

# %% [markdown]
# ## Rearrangement Exp 1

# %%
import asyncio
from pytweezer.coordinators.rearrangement import Rearrangement
import time

coordinator = Rearrangement({"camera": hamcam, "slm": slm, "phasemask_generator": PM}, {})

data1 = np.stack(terms1[:4])
data2 = np.stack(terms2[:4])
await asyncio.to_thread(
    coordinator.initialise,
    terms1, terms2,
    d0=0.5, fps=1/(1e-6), threshold=an.convert_photons_to_counts(threshold_1)*1.1,
    grid_positions=grid_positions, profile="linear", window_size=5, feature_size=10, 
    detector=scorer, num_images=1
)
# Out:
# Occupancy via PSF detector (window 9, threshold 19.8).
# Rearrangement node initialised.

# %%
# Experiment and camera setup
n_iterations = 1
exp.set_motmaster_experiment("RbTweezerBasic2026_2")
exp.set_iterations(n_iterations)
exp.set_save_toggle(False)
exp.set_run_until_stopped(False)
# Out:
# {'ok': True,
#  'command': 'interface_method',
#  'method': 'set_run_until_stopped',
#  'state': 'accepted'}

# %%
N_iterations = 100  # adjust before running
imgs_software = []
err_indices = []
timings_log = []

for it in range(N_iterations):
    print(f"Running experiment iteration {it+1} / {N_iterations}")
    rearrangement_task = asyncio.create_task(asyncio.to_thread(coordinator.arm_rearrangement))

    time.sleep(0.1)
    exp.start_motmaster_experiment({
                "tMOTLoadRepVCO": ExpParams.get_parameter("tMOTLoadRepVCO"), "tMOTLoadCoolVCO": ExpParams.get_parameter("tMOTLoadCoolVCO"),
                "tMOTLoadRepVVA": ExpParams.get_parameter("tMOTLoadRepVVA"), "tMOTLoadCoolVVA": ExpParams.get_parameter("tMOTLoadCoolVVA"),
                "tMolCoolVCO1": ExpParams.get_parameter("tMolCoolVCO1"), "tMolRepVCO1": ExpParams.get_parameter("tMolRepVCO1"), 
                "tMolCoolVVA1": ExpParams.get_parameter("tMolCoolVVA1"), "tMolRepVVA1": ExpParams.get_parameter("tMolRepVVA1"),
                "tMolCoolVCO2": ExpParams.get_parameter("tMolCoolVCO2"), "tMolRepVCO2": ExpParams.get_parameter("tMolRepVCO2"), 
                "tMolCoolVVA2": ExpParams.get_parameter("tMolCoolVVA2"), "tMolRepVVA2": ExpParams.get_parameter("tMolRepVVA2"),
                "tImgCoolVCO1": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA1": ExpParams.get_parameter("tImgCoolVVA"), 
                "tImgCoolVCO2": ExpParams.get_parameter("tImgCoolVCO"), "tImgCoolVVA2": ExpParams.get_parameter("tImgCoolVVA"),
                "tMolassesShimXccValue": ExpParams.get_parameter("tMolassesShimXccValue"), "tMolassesShimYccValue": ExpParams.get_parameter("tMolassesShimYccValue"), "tMolassesShimZccValue": ExpParams.get_parameter("tMolassesShimZccValue"),
                "tMOTShimXccValue": ExpParams.get_parameter("tMOTShimXccValue"), "tMOTShimYccValue": ExpParams.get_parameter("tMOTShimYccValue"), "tMOTShimZccValue": ExpParams.get_parameter("tMOTShimZccValue"),
                "BackgroundDrop": 0, "tTweezerSetVVA0": 8.0, "tTweezerSetVVA1": 10.0, "tDelay2": 5000})
    img0, imgs1, timings = await rearrangement_task
    print("Images acquired from rearrangement node.")

    if imgs1.sum() == 0:
        print(f"Empty image received at iteration {it+1}. Discarding...")
        err_indices.append(it)
    else:
        imgs_software.append([img0, *imgs1])
        timings_log.append(timings)

mean_rearrangement_time_ms = np.mean([t['total_rearrangement_ms'] for t in timings_log])
mean_calc_upload_time_ms = np.mean([t['calculation_and_upload_ms'] for t in timings_log])
mean_nframes = np.mean([t['n_frames'] for t in timings_log])
mean_speed = mean_rearrangement_time_ms / mean_nframes
mean_calc_upload_speed = mean_calc_upload_time_ms / mean_nframes
print(f"Average total rearrangement time = {mean_rearrangement_time_ms:.2f} ms")
print(f"Average number of frames = {mean_nframes:.2f}")
print(f"Average total speed = {mean_speed:.2f} ms/frame")
print(f"Average calculation and upload speed = {mean_calc_upload_speed:.2f} ms/frame")
# Out:
# Running experiment iteration 1 / 100
# Rearrangement complete: 23 frames, 20.2394ms total (occupancy 0.1680ms, calculation+upload 20.0714ms).
# Images acquired from rearrangement node.
# Running experiment iteration 2 / 100
# Rearrangement complete: 23 frames, 19.7819ms total (occupancy 0.1325ms, calculation+upload 19.6494ms).
# Images acquired from rearrangement node.
# Running experiment iteration 3 / 100
# Rearrangement complete: 32 frames, 25.9909ms total (occupancy 0.1301ms, calculation+upload 25.8608ms).
# Images acquired from rearrangement node.
# Running experiment iteration 4 / 100
# Rearrangement complete: 29 frames, 24.1209ms total (occupancy 0.1305ms, calculation+upload 23.9904ms).
# Images acquired from rearrangement node.
# Running experiment iteration 5 / 100
# Rearrangement complete: 29 frames, 23.9166ms total (occupancy 0.1300ms, calculation+upload 23.7866ms).
# Images acquired from rearrangement node.
# Running experiment iteration 6 / 100
# Rearrangement complete: 23 frames, 19.6076ms total (occupancy 0.1344ms, calculation+upload 19.4732ms).
# Images acquired from rearrangement node.
# Running experiment iteration 7 / 100
# Rearrangement complete: 23 frames, 19.6281ms total (occupancy 0.2172ms, calculation+upload 19.4109ms).
# Images acquired from rearrangement node.
# Running experiment iteration 8 / 100
# Rearrangement complete: 23 frames, 19.4087ms total (occupancy 0.1330ms, calculation+upload 19.2757ms).
# Images acquired from rearrangement node.
# Running experiment iteration 9 / 100
# Rearrangement complete: 23 frames, 20.0490ms total (occupancy 0.1326ms, calculation+upload 19.9164ms).
# Images acquired from rearrangement node.
# Running experiment iteration 10 / 100
# Rearrangement complete: 23 frames, 19.9237ms total (occupancy 0.1328ms, calculation+upload 19.7909ms).
# Images acquired from rearrangement node.
# Running experiment iteration 11 / 100
# Rearrangement complete: 23 frames, 19.5115ms total (occupancy 0.1257ms, calculation+upload 19.3858ms).
# Images acquired from rearrangement node.
# Running experiment iteration 12 / 100
# Rearrangement complete: 29 frames, 23.8123ms total (occupancy 0.1285ms, calculation+upload 23.6838ms).
# Images acquired from rearrangement node.
# Running experiment iteration 13 / 100
# Rearrangement complete: 29 frames, 24.1020ms total (occupancy 0.1344ms, calculation+upload 23.9676ms).
# Images acquired from rearrangement node.
# Running experiment iteration 14 / 100
# Rearrangement complete: 29 frames, 24.0975ms total (occupancy 0.2164ms, calculation+upload 23.8811ms).
# Images acquired from rearrangement node.
# Running experiment iteration 15 / 100
# Rearrangement complete: 23 frames, 19.7664ms total (occupancy 0.1259ms, calculation+upload 19.6405ms).
# Images acquired from rearrangement node.
# Running experiment iteration 16 / 100
# Rearrangement complete: 23 frames, 19.9197ms total (occupancy 0.1290ms, calculation+upload 19.7907ms).
# Images acquired from rearrangement node.
# Running experiment iteration 17 / 100
# Rearrangement complete: 23 frames, 19.7020ms total (occupancy 0.1300ms, calculation+upload 19.5720ms).
# Images acquired from rearrangement node.
# Running experiment iteration 18 / 100
# Rearrangement complete: 23 frames, 19.9010ms total (occupancy 0.1306ms, calculation+upload 19.7704ms).
# Images acquired from rearrangement node.
# Running experiment iteration 19 / 100
# Rearrangement complete: 29 frames, 24.3255ms total (occupancy 0.1558ms, calculation+upload 24.1697ms).
# Images acquired from rearrangement node.
# Running experiment iteration 20 / 100
# Rearrangement complete: 23 frames, 19.6936ms total (occupancy 0.1701ms, calculation+upload 19.5235ms).
# Images acquired from rearrangement node.
# Running experiment iteration 21 / 100
# Rearrangement complete: 23 frames, 19.4491ms total (occupancy 0.1591ms, calculation+upload 19.2900ms).
# Images acquired from rearrangement node.
# Running experiment iteration 22 / 100
# Rearrangement complete: 29 frames, 24.0791ms total (occupancy 0.1255ms, calculation+upload 23.9536ms).
# Images acquired from rearrangement node.
# Running experiment iteration 23 / 100
# Rearrangement complete: 29 frames, 23.8640ms total (occupancy 0.1239ms, calculation+upload 23.7401ms).
# Images acquired from rearrangement node.
# Running experiment iteration 24 / 100
# Rearrangement complete: 29 frames, 23.5840ms total (occupancy 0.1250ms, calculation+upload 23.4590ms).
# Images acquired from rearrangement node.
# Running experiment iteration 25 / 100
# Rearrangement complete: 23 frames, 19.5005ms total (occupancy 0.1662ms, calculation+upload 19.3343ms).
# Images acquired from rearrangement node.
# Running experiment iteration 26 / 100
# Rearrangement complete: 32 frames, 25.7935ms total (occupancy 0.1642ms, calculation+upload 25.6293ms).
# Images acquired from rearrangement node.
# Running experiment iteration 27 / 100
# Rearrangement complete: 29 frames, 24.1701ms total (occupancy 0.1661ms, calculation+upload 24.0040ms).
# Images acquired from rearrangement node.
# Running experiment iteration 28 / 100
# Rearrangement complete: 23 frames, 19.4241ms total (occupancy 0.1287ms, calculation+upload 19.2954ms).
# Images acquired from rearrangement node.
# Running experiment iteration 29 / 100
# Rearrangement complete: 23 frames, 19.8744ms total (occupancy 0.1645ms, calculation+upload 19.7099ms).
# Images acquired from rearrangement node.
# Running experiment iteration 30 / 100
# Rearrangement complete: 29 frames, 23.7785ms total (occupancy 0.1305ms, calculation+upload 23.6480ms).
# Images acquired from rearrangement node.
# Running experiment iteration 31 / 100
# Rearrangement complete: 23 frames, 19.8221ms total (occupancy 0.1515ms, calculation+upload 19.6706ms).
# Images acquired from rearrangement node.
# Running experiment iteration 32 / 100
# Rearrangement complete: 23 frames, 20.0007ms total (occupancy 0.1578ms, calculation+upload 19.8429ms).
# Images acquired from rearrangement node.
# Running experiment iteration 33 / 100
# Rearrangement complete: 29 frames, 24.1213ms total (occupancy 0.1473ms, calculation+upload 23.9740ms).
# Images acquired from rearrangement node.
# Running experiment iteration 34 / 100
# Rearrangement complete: 29 frames, 24.1837ms total (occupancy 0.1605ms, calculation+upload 24.0232ms).
# Images acquired from rearrangement node.
# Running experiment iteration 35 / 100
# Rearrangement complete: 23 frames, 20.2342ms total (occupancy 0.1925ms, calculation+upload 20.0417ms).
# Images acquired from rearrangement node.
# Running experiment iteration 36 / 100
# Rearrangement complete: 23 frames, 20.0643ms total (occupancy 0.1521ms, calculation+upload 19.9122ms).
# Images acquired from rearrangement node.
# Running experiment iteration 37 / 100
# Rearrangement complete: 29 frames, 24.1041ms total (occupancy 0.1602ms, calculation+upload 23.9439ms).
# Images acquired from rearrangement node.
# Running experiment iteration 38 / 100
# Rearrangement complete: 29 frames, 23.6700ms total (occupancy 0.1422ms, calculation+upload 23.5278ms).
# Images acquired from rearrangement node.
# Running experiment iteration 39 / 100
# Rearrangement complete: 23 frames, 20.0187ms total (occupancy 0.2103ms, calculation+upload 19.8084ms).
# Images acquired from rearrangement node.
# Running experiment iteration 40 / 100
# Rearrangement complete: 29 frames, 23.8808ms total (occupancy 0.1440ms, calculation+upload 23.7368ms).
# Images acquired from rearrangement node.
# Running experiment iteration 41 / 100
# Rearrangement complete: 23 frames, 20.1351ms total (occupancy 0.2687ms, calculation+upload 19.8664ms).
# Images acquired from rearrangement node.
# Running experiment iteration 42 / 100
# Rearrangement complete: 29 frames, 24.2583ms total (occupancy 0.2305ms, calculation+upload 24.0278ms).
# Images acquired from rearrangement node.
# Running experiment iteration 43 / 100
# Rearrangement complete: 30 frames, 25.0121ms total (occupancy 0.1588ms, calculation+upload 24.8533ms).
# Images acquired from rearrangement node.
# Running experiment iteration 44 / 100
# Rearrangement complete: 23 frames, 19.7467ms total (occupancy 0.1582ms, calculation+upload 19.5885ms).
# Images acquired from rearrangement node.
# Running experiment iteration 45 / 100
# Rearrangement complete: 23 frames, 19.6661ms total (occupancy 0.1775ms, calculation+upload 19.4886ms).
# Images acquired from rearrangement node.
# Running experiment iteration 46 / 100
# Rearrangement complete: 23 frames, 19.7311ms total (occupancy 0.1469ms, calculation+upload 19.5842ms).
# Images acquired from rearrangement node.
# Running experiment iteration 47 / 100
# Rearrangement complete: 23 frames, 19.8115ms total (occupancy 0.1473ms, calculation+upload 19.6642ms).
# Images acquired from rearrangement node.
# Running experiment iteration 48 / 100
# Rearrangement complete: 23 frames, 19.4566ms total (occupancy 0.1311ms, calculation+upload 19.3255ms).
# Images acquired from rearrangement node.
# Running experiment iteration 49 / 100
# Rearrangement complete: 23 frames, 19.7776ms total (occupancy 0.1671ms, calculation+upload 19.6105ms).
# Images acquired from rearrangement node.
# Running experiment iteration 50 / 100
# Rearrangement complete: 23 frames, 20.0283ms total (occupancy 0.1621ms, calculation+upload 19.8662ms).
# Images acquired from rearrangement node.
# Running experiment iteration 51 / 100
# Rearrangement complete: 23 frames, 19.7621ms total (occupancy 0.1519ms, calculation+upload 19.6102ms).
# Images acquired from rearrangement node.
# Running experiment iteration 52 / 100
# Rearrangement complete: 29 frames, 24.5377ms total (occupancy 0.2706ms, calculation+upload 24.2671ms).
# Images acquired from rearrangement node.
# Running experiment iteration 53 / 100
# Rearrangement complete: 23 frames, 19.9383ms total (occupancy 0.1457ms, calculation+upload 19.7926ms).
# Images acquired from rearrangement node.
# Running experiment iteration 54 / 100
# Rearrangement complete: 32 frames, 26.4094ms total (occupancy 0.2562ms, calculation+upload 26.1532ms).
# Images acquired from rearrangement node.
# Running experiment iteration 55 / 100
# Rearrangement complete: 23 frames, 19.6807ms total (occupancy 0.1600ms, calculation+upload 19.5207ms).
# Images acquired from rearrangement node.
# Running experiment iteration 56 / 100
# Rearrangement complete: 23 frames, 19.4311ms total (occupancy 0.1526ms, calculation+upload 19.2785ms).
# Images acquired from rearrangement node.
# Running experiment iteration 57 / 100
# Rearrangement complete: 30 frames, 24.9773ms total (occupancy 0.1640ms, calculation+upload 24.8133ms).
# Images acquired from rearrangement node.
# Running experiment iteration 58 / 100
# Rearrangement complete: 23 frames, 19.8805ms total (occupancy 0.2476ms, calculation+upload 19.6329ms).
# Images acquired from rearrangement node.
# Running experiment iteration 59 / 100
# Rearrangement complete: 29 frames, 23.9588ms total (occupancy 0.2532ms, calculation+upload 23.7056ms).
# Images acquired from rearrangement node.
# Running experiment iteration 60 / 100
# Rearrangement complete: 37 frames, 29.6812ms total (occupancy 0.2638ms, calculation+upload 29.4174ms).
# Images acquired from rearrangement node.
# Running experiment iteration 61 / 100
# Rearrangement complete: 29 frames, 23.7102ms total (occupancy 0.1513ms, calculation+upload 23.5589ms).
# Images acquired from rearrangement node.
# Running experiment iteration 62 / 100
# Rearrangement complete: 23 frames, 20.0626ms total (occupancy 0.2588ms, calculation+upload 19.8038ms).
# Images acquired from rearrangement node.
# Running experiment iteration 63 / 100
# Rearrangement complete: 29 frames, 24.1464ms total (occupancy 0.1584ms, calculation+upload 23.9880ms).
# Images acquired from rearrangement node.
# Running experiment iteration 64 / 100
# Rearrangement complete: 23 frames, 19.5310ms total (occupancy 0.1493ms, calculation+upload 19.3817ms).
# Images acquired from rearrangement node.
# Running experiment iteration 65 / 100
# Rearrangement complete: 30 frames, 24.6949ms total (occupancy 0.1508ms, calculation+upload 24.5441ms).
# Images acquired from rearrangement node.
# Running experiment iteration 66 / 100
# Rearrangement complete: 23 frames, 20.0227ms total (occupancy 0.1718ms, calculation+upload 19.8509ms).
# Images acquired from rearrangement node.
# Running experiment iteration 67 / 100
# Rearrangement complete: 23 frames, 19.8187ms total (occupancy 0.2554ms, calculation+upload 19.5633ms).
# Images acquired from rearrangement node.
# Running experiment iteration 68 / 100
# Rearrangement complete: 37 frames, 29.4916ms total (occupancy 0.1538ms, calculation+upload 29.3378ms).
# Images acquired from rearrangement node.
# Running experiment iteration 69 / 100
# Rearrangement complete: 23 frames, 19.9197ms total (occupancy 0.1599ms, calculation+upload 19.7598ms).
# Images acquired from rearrangement node.
# Running experiment iteration 70 / 100
# Rearrangement complete: 23 frames, 19.9889ms total (occupancy 0.1567ms, calculation+upload 19.8322ms).
# Images acquired from rearrangement node.
# Running experiment iteration 71 / 100
# Rearrangement complete: 23 frames, 19.4414ms total (occupancy 0.1498ms, calculation+upload 19.2916ms).
# Images acquired from rearrangement node.
# Running experiment iteration 72 / 100
# Rearrangement complete: 23 frames, 20.0608ms total (occupancy 0.1588ms, calculation+upload 19.9020ms).
# Images acquired from rearrangement node.
# Running experiment iteration 73 / 100
# Rearrangement complete: 29 frames, 24.2227ms total (occupancy 0.1525ms, calculation+upload 24.0702ms).
# Images acquired from rearrangement node.
# Running experiment iteration 74 / 100
# Rearrangement complete: 23 frames, 19.7400ms total (occupancy 0.2197ms, calculation+upload 19.5203ms).
# Images acquired from rearrangement node.
# Running experiment iteration 75 / 100
# Rearrangement complete: 29 frames, 24.0559ms total (occupancy 0.2757ms, calculation+upload 23.7802ms).
# Images acquired from rearrangement node.
# Running experiment iteration 76 / 100
# Rearrangement complete: 23 frames, 19.9622ms total (occupancy 0.1514ms, calculation+upload 19.8108ms).
# Images acquired from rearrangement node.
# Running experiment iteration 77 / 100
# Rearrangement complete: 29 frames, 24.0666ms total (occupancy 0.2434ms, calculation+upload 23.8232ms).
# Images acquired from rearrangement node.
# Running experiment iteration 78 / 100
# Rearrangement complete: 29 frames, 24.1059ms total (occupancy 0.1661ms, calculation+upload 23.9398ms).
# Images acquired from rearrangement node.
# Running experiment iteration 79 / 100
# Rearrangement complete: 29 frames, 24.1272ms total (occupancy 0.1807ms, calculation+upload 23.9465ms).
# Images acquired from rearrangement node.
# Running experiment iteration 80 / 100
# Rearrangement complete: 23 frames, 19.6482ms total (occupancy 0.1494ms, calculation+upload 19.4988ms).
# Images acquired from rearrangement node.
# Running experiment iteration 81 / 100
# Rearrangement complete: 23 frames, 20.2125ms total (occupancy 0.2571ms, calculation+upload 19.9554ms).
# Images acquired from rearrangement node.
# Running experiment iteration 82 / 100
# Rearrangement complete: 29 frames, 24.5049ms total (occupancy 0.1699ms, calculation+upload 24.3350ms).
# Images acquired from rearrangement node.
# Running experiment iteration 83 / 100
# Rearrangement complete: 29 frames, 24.2003ms total (occupancy 0.1588ms, calculation+upload 24.0415ms).
# Images acquired from rearrangement node.
# Running experiment iteration 84 / 100
# Rearrangement complete: 23 frames, 19.5565ms total (occupancy 0.1534ms, calculation+upload 19.4031ms).
# Images acquired from rearrangement node.
# Running experiment iteration 85 / 100
# Rearrangement complete: 23 frames, 19.8817ms total (occupancy 0.2736ms, calculation+upload 19.6081ms).
# Images acquired from rearrangement node.
# Running experiment iteration 86 / 100
# Rearrangement complete: 23 frames, 19.8451ms total (occupancy 0.1593ms, calculation+upload 19.6858ms).
# Images acquired from rearrangement node.
# Running experiment iteration 87 / 100
# Rearrangement complete: 37 frames, 29.1305ms total (occupancy 0.1554ms, calculation+upload 28.9751ms).
# Images acquired from rearrangement node.
# Running experiment iteration 88 / 100
# Rearrangement complete: 23 frames, 19.9679ms total (occupancy 0.2575ms, calculation+upload 19.7104ms).
# Images acquired from rearrangement node.
# Running experiment iteration 89 / 100
# Rearrangement complete: 23 frames, 19.9715ms total (occupancy 0.1579ms, calculation+upload 19.8136ms).
# Images acquired from rearrangement node.
# Running experiment iteration 90 / 100
# Rearrangement complete: 23 frames, 19.7048ms total (occupancy 0.1471ms, calculation+upload 19.5577ms).
# Images acquired from rearrangement node.
# Running experiment iteration 91 / 100
# Rearrangement complete: 29 frames, 24.3414ms total (occupancy 0.2537ms, calculation+upload 24.0877ms).
# Images acquired from rearrangement node.
# Running experiment iteration 92 / 100
# Rearrangement complete: 23 frames, 19.5029ms total (occupancy 0.1557ms, calculation+upload 19.3472ms).
# Images acquired from rearrangement node.
# Running experiment iteration 93 / 100
# Rearrangement complete: 23 frames, 19.9523ms total (occupancy 0.1547ms, calculation+upload 19.7976ms).
# Images acquired from rearrangement node.
# Running experiment iteration 94 / 100
# Rearrangement complete: 23 frames, 19.8210ms total (occupancy 0.1534ms, calculation+upload 19.6676ms).
# Images acquired from rearrangement node.
# Running experiment iteration 95 / 100
# Rearrangement complete: 23 frames, 19.4015ms total (occupancy 0.1487ms, calculation+upload 19.2528ms).
# Images acquired from rearrangement node.
# Running experiment iteration 96 / 100
# Rearrangement complete: 29 frames, 23.7791ms total (occupancy 0.1567ms, calculation+upload 23.6224ms).
# Images acquired from rearrangement node.
# Running experiment iteration 97 / 100
# Rearrangement complete: 37 frames, 29.7870ms total (occupancy 0.1729ms, calculation+upload 29.6141ms).
# Images acquired from rearrangement node.
# Running experiment iteration 98 / 100
# Rearrangement complete: 23 frames, 19.7187ms total (occupancy 0.1557ms, calculation+upload 19.5630ms).
# Images acquired from rearrangement node.
# Running experiment iteration 99 / 100
# Rearrangement complete: 29 frames, 24.2210ms total (occupancy 0.1514ms, calculation+upload 24.0696ms).
# Images acquired from rearrangement node.
# Running experiment iteration 100 / 100
# Rearrangement complete: 23 frames, 20.2823ms total (occupancy 0.2792ms, calculation+upload 20.0031ms).
# Images acquired from rearrangement node.
# Average total rearrangement time = 21.86 ms
# Average number of frames = 25.90
# Average total speed = 0.84 ms/frame
# Average calculation and upload speed = 0.84 ms/frame

# %%
num_imgs_per_it = 2
tot_imgs = np.array(imgs_software)

plt.figure(figsize=(6*num_imgs_per_it, 6))
for n in range(num_imgs_per_it):
    imgs_n = tot_imgs[:, n, :, :]
    imgs__n_mean = imgs_n.mean(axis=0)
    imgs_n_mean_filtered = an.morphological_tophat_high_pass(imgs__n_mean, feature_size=feature_size)

    plt.subplot(1, num_imgs_per_it, n + 1)
    plt.imshow(imgs_n_mean_filtered, cmap='magma', vmax=0.6*imgs_n_mean_filtered.max())
    plt.title(f'Filtered Image {n}')
    plt.axis('off')
    
plt.show()

# %%
n = 0
imgs_n = tot_imgs[:, n, :, :]
imgs_n_filtered = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs_n]
photons, loading_probabilities, threshold, fidelity = an.get_array_loading_statistics(imgs_n_filtered, grid_positions, threshold=25, window_size=5, binning=60, 
                                                                                        show_histogram=True, scorer=scorer, threshold_detection=True, verbose=True, show_site_labels=True)
# Out:
# Trap (0) Loading Probability : 51.00 %
# Trap (1) Loading Probability : 49.00 %
# Trap (2) Loading Probability : 51.00 %
# Trap (3) Loading Probability : 54.00 %
# Trap (4) Loading Probability : 62.00 %
# Trap (5) Loading Probability : 54.00 %
# Trap (6) Loading Probability : 52.00 %
# Trap (7) Loading Probability : 46.00 %
# Trap (8) Loading Probability : 64.00 %
# Trap (9) Loading Probability : 61.00 %
# Trap (10) Loading Probability : 60.00 %
# Trap (11) Loading Probability : 59.00 %
# Trap (12) Loading Probability : 66.00 %
# Trap (13) Loading Probability : 51.00 %
# Trap (14) Loading Probability : 63.00 %
# Trap (15) Loading Probability : 50.00 %
# Trap (16) Loading Probability : 54.00 %
# Trap (17) Loading Probability : 61.00 %
# Trap (18) Loading Probability : 59.00 %
# Trap (19) Loading Probability : 61.00 %
# Trap (20) Loading Probability : 51.00 %
# Trap (21) Loading Probability : 63.00 %
# Trap (22) Loading Probability : 50.00 %
# Trap (23) Loading Probability : 51.00 %
# Trap (24) Loading Probability : 67.00 %
# Trap (25) Loading Probability : 54.00 %
# Trap (26) Loading Probability : 51.00 %
# Trap (27) Loading Probability : 54.00 %
# Trap (28) Loading Probability : 58.00 %
# Trap (29) Loading Probability : 58.00 %
# Trap (30) Loading Probability : 59.00 %
# Trap (31) Loading Probability : 52.00 %
# Trap (32) Loading Probability : 60.00 %
# Trap (33) Loading Probability : 61.00 %
# Trap (34) Loading Probability : 57.00 %
# Trap (35) Loading Probability : 68.00 %
# Trap (36) Loading Probability : 66.00 %
# Trap (37) Loading Probability : 62.00 %
# Trap (38) Loading Probability : 60.00 %
# Trap (39) Loading Probability : 57.00 %
# Trap (40) Loading Probability : 57.00 %
# Trap (41) Loading Probability : 59.00 %
# Trap (42) Loading Probability : 63.00 %
# Trap (43) Loading Probability : 55.00 %
# Trap (44) Loading Probability : 56.00 %
# Trap (45) Loading Probability : 51.00 %
# Trap (46) Loading Probability : 57.00 %
# Trap (47) Loading Probability : 55.00 %
# Trap (48) Loading Probability : 61.00 %
# Trap (49) Loading Probability : 60.00 %
# Trap (50) Loading Probability : 54.00 %
# Trap (51) Loading Probability : 59.00 %
# Trap (52) Loading Probability : 58.00 %
# Trap (53) Loading Probability : 52.00 %
# Trap (54) Loading Probability : 58.00 %
# Trap (55) Loading Probability : 57.00 %
# Trap (56) Loading Probability : 68.00 %
# Trap (57) Loading Probability : 52.00 %
# Trap (58) Loading Probability : 51.00 %
# Trap (59) Loading Probability : 58.00 %
# Trap (60) Loading Probability : 65.00 %
# Trap (61) Loading Probability : 52.00 %
# Trap (62) Loading Probability : 57.00 %
# Trap (63) Loading Probability : 66.00 %
# Trap (64) Loading Probability : 55.00 %
# Trap (65) Loading Probability : 57.00 %
# Trap (66) Loading Probability : 52.00 %
# Trap (67) Loading Probability : 50.00 %
# Trap (68) Loading Probability : 46.00 %
# Trap (69) Loading Probability : 52.00 %
# Trap (70) Loading Probability : 54.00 %
# Trap (71) Loading Probability : 57.00 %
# Trap (72) Loading Probability : 66.00 %
# Trap (73) Loading Probability : 56.00 %
# Trap (74) Loading Probability : 55.00 %
# Trap (75) Loading Probability : 57.00 %
# Trap (76) Loading Probability : 54.00 %
# Trap (77) Loading Probability : 50.00 %
# Trap (78) Loading Probability : 61.00 %
# Trap (79) Loading Probability : 59.00 %
# Trap (80) Loading Probability : 57.00 %
# Trap (81) Loading Probability : 50.00 %
# Trap (82) Loading Probability : 52.00 %
# Trap (83) Loading Probability : 62.00 %
# Trap (84) Loading Probability : 64.00 %
# Trap (85) Loading Probability : 57.00 %
# Trap (86) Loading Probability : 53.00 %
# Trap (87) Loading Probability : 56.00 %
# Trap (88) Loading Probability : 55.00 %
# Trap (89) Loading Probability : 59.00 %
# Trap (90) Loading Probability : 49.00 %
# Trap (91) Loading Probability : 64.00 %
# Trap (92) Loading Probability : 59.00 %
# Trap (93) Loading Probability : 52.00 %
# Trap (94) Loading Probability : 55.00 %
# Trap (95) Loading Probability : 46.00 %
# Trap (96) Loading Probability : 56.00 %
# Trap (97) Loading Probability : 59.00 %
# Trap (98) Loading Probability : 48.00 %
# Trap (99) Loading Probability : 68.00 %
# Trap (100) Loading Probability : 58.00 %
# Trap (101) Loading Probability : 60.00 %
# Trap (102) Loading Probability : 56.00 %
# Trap (103) Loading Probability : 61.00 %
# Trap (104) Loading Probability : 58.00 %
# Trap (105) Loading Probability : 60.00 %
# Trap (106) Loading Probability : 54.00 %
# Trap (107) Loading Probability : 58.00 %
# Trap (108) Loading Probability : 55.00 %
# Trap (109) Loading Probability : 51.00 %
# Trap (110) Loading Probability : 61.00 %
# Trap (111) Loading Probability : 54.00 %
# Trap (112) Loading Probability : 59.00 %
# Trap (113) Loading Probability : 66.00 %
# Trap (114) Loading Probability : 50.00 %
# Trap (115) Loading Probability : 52.00 %
# Trap (116) Loading Probability : 58.00 %
# Trap (117) Loading Probability : 56.00 %
# Trap (118) Loading Probability : 60.00 %
# Trap (119) Loading Probability : 51.00 %
# Trap (120) Loading Probability : 65.00 %
# Trap (121) Loading Probability : 60.00 %
# Trap (122) Loading Probability : 61.00 %
# Trap (123) Loading Probability : 60.00 %
# Trap (124) Loading Probability : 57.00 %
# Trap (125) Loading Probability : 49.00 %
# Trap (126) Loading Probability : 63.00 %
# Trap (127) Loading Probability : 55.00 %
# Trap (128) Loading Probability : 57.00 %
# Trap (129) Loading Probability : 64.00 %
# Trap (130) Loading Probability : 53.00 %
# Trap (131) Loading Probability : 59.00 %
# Trap (132) Loading Probability : 54.00 %
# Trap (133) Loading Probability : 60.00 %
# Trap (134) Loading Probability : 57.00 %
# Trap (135) Loading Probability : 62.00 %
# Trap (136) Loading Probability : 61.00 %
# Trap (137) Loading Probability : 54.00 %
# Trap (138) Loading Probability : 59.00 %
# Trap (139) Loading Probability : 49.00 %
# Trap (140) Loading Probability : 57.00 %
# Trap (141) Loading Probability : 56.00 %
# Trap (142) Loading Probability : 56.00 %
# Trap (143) Loading Probability : 60.00 %
# Trap (144) Loading Probability : 57.00 %
# Trap (145) Loading Probability : 60.00 %
# Trap (146) Loading Probability : 61.00 %
# Trap (147) Loading Probability : 45.00 %
# Trap (148) Loading Probability : 58.00 %
# Trap (149) Loading Probability : 57.00 %
# Trap (150) Loading Probability : 54.00 %
# Trap (151) Loading Probability : 56.00 %
# Trap (152) Loading Probability : 60.00 %
# Trap (153) Loading Probability : 62.00 %
# Trap (154) Loading Probability : 60.00 %
# Trap (155) Loading Probability : 54.00 %
# Trap (156) Loading Probability : 58.00 %
# Trap (157) Loading Probability : 60.00 %
# Trap (158) Loading Probability : 57.00 %
# Trap (159) Loading Probability : 56.00 %
# Trap (160) Loading Probability : 56.00 %
# Trap (161) Loading Probability : 60.00 %
# Trap (162) Loading Probability : 58.00 %
# Trap (163) Loading Probability : 54.00 %
# Trap (164) Loading Probability : 69.00 %
# Trap (165) Loading Probability : 61.00 %
# Trap (166) Loading Probability : 57.00 %
# Trap (167) Loading Probability : 62.00 %
# Trap (168) Loading Probability : 48.00 %
# Trap (169) Loading Probability : 69.00 %
# Trap (170) Loading Probability : 56.00 %
# Trap (171) Loading Probability : 55.00 %
# Trap (172) Loading Probability : 59.00 %
# Trap (173) Loading Probability : 46.00 %
# Trap (174) Loading Probability : 60.00 %
# Trap (175) Loading Probability : 57.00 %
# Trap (176) Loading Probability : 52.00 %
# Trap (177) Loading Probability : 60.00 %
# Trap (178) Loading Probability : 55.00 %
# Trap (179) Loading Probability : 53.00 %
# Trap (180) Loading Probability : 48.00 %
# Trap (181) Loading Probability : 55.00 %
# Trap (182) Loading Probability : 62.00 %
# Trap (183) Loading Probability : 53.00 %
# Trap (184) Loading Probability : 57.00 %
# Trap (185) Loading Probability : 52.00 %
# Trap (186) Loading Probability : 52.00 %
# Trap (187) Loading Probability : 64.00 %
# Trap (188) Loading Probability : 59.00 %
# Trap (189) Loading Probability : 58.00 %
# Trap (190) Loading Probability : 55.00 %
# Trap (191) Loading Probability : 53.00 %
# Trap (192) Loading Probability : 50.00 %
# Trap (193) Loading Probability : 56.00 %
# Trap (194) Loading Probability : 56.00 %
# Trap (195) Loading Probability : 53.00 %
# Detected Loading Threshold: 19.59 photons
# Std dev of Loading Probabilities: 8.63 %
# Mean Loading Probability: 56.84 %
# Detection Fidelity: 99.87 %
# Mean Background Photon Count: -25.47 photons, Variance: 196.11 photons^2
# Mean Signal Photon Count: 127.25 photons, Variance: 1379.45 photons^2

# %%
n = 1
imgs_n = tot_imgs[:, n, :, :]
imgs_n_mean = imgs_n.mean(axis=0)
imgs_n_mean_filtered = an.morphological_tophat_high_pass(imgs_n_mean, feature_size=feature_size)

feature_size, window = 10, 5
grid_positions_2, _ = an.detect_trap_sites(imgs_n_mean_filtered, 10*10, detection_step=100)

imgs_n_filtered = [an.morphological_tophat_high_pass(img, feature_size=feature_size) for img in imgs_n]
photons, loading_probabilities, threshold, fidelity = an.get_array_loading_statistics(imgs_n_filtered, grid_positions_2, threshold=70, window_size=5, binning=60, 
                                                                                        show_histogram=True, threshold_detection=False, verbose=True, show_site_labels=True)
# Out:
# Looking for trap sites...
# 100 Atoms Detected.
# Trap (0) Loading Probability : 50.00 %
# Trap (1) Loading Probability : 63.00 %
# Trap (2) Loading Probability : 57.00 %
# Trap (3) Loading Probability : 58.00 %
# Trap (4) Loading Probability : 48.00 %
# Trap (5) Loading Probability : 65.00 %
# Trap (6) Loading Probability : 60.00 %
# Trap (7) Loading Probability : 55.00 %
# Trap (8) Loading Probability : 58.00 %
# Trap (9) Loading Probability : 51.00 %
# Trap (10) Loading Probability : 54.00 %
# Trap (11) Loading Probability : 66.00 %
# Trap (12) Loading Probability : 54.00 %
# Trap (13) Loading Probability : 54.00 %
# Trap (14) Loading Probability : 59.00 %
# Trap (15) Loading Probability : 60.00 %
# Trap (16) Loading Probability : 61.00 %
# Trap (17) Loading Probability : 53.00 %
# Trap (18) Loading Probability : 57.00 %
# Trap (19) Loading Probability : 54.00 %
# Trap (20) Loading Probability : 64.00 %
# Trap (21) Loading Probability : 63.00 %
# Trap (22) Loading Probability : 60.00 %
# Trap (23) Loading Probability : 59.00 %
# Trap (24) Loading Probability : 57.00 %
# Trap (25) Loading Probability : 59.00 %
# Trap (26) Loading Probability : 54.00 %
# Trap (27) Loading Probability : 55.00 %
# Trap (28) Loading Probability : 57.00 %
# Trap (29) Loading Probability : 53.00 %
# Trap (30) Loading Probability : 55.00 %
# Trap (31) Loading Probability : 63.00 %
# Trap (32) Loading Probability : 62.00 %
# Trap (33) Loading Probability : 61.00 %
# Trap (34) Loading Probability : 53.00 %
# Trap (35) Loading Probability : 57.00 %
# Trap (36) Loading Probability : 54.00 %
# Trap (37) Loading Probability : 49.00 %
# Trap (38) Loading Probability : 51.00 %
# Trap (39) Loading Probability : 52.00 %
# Trap (40) Loading Probability : 53.00 %
# Trap (41) Loading Probability : 51.00 %
# Trap (42) Loading Probability : 62.00 %
# Trap (43) Loading Probability : 55.00 %
# Trap (44) Loading Probability : 57.00 %
# Trap (45) Loading Probability : 62.00 %
# Trap (46) Loading Probability : 50.00 %
# Trap (47) Loading Probability : 59.00 %
# Trap (48) Loading Probability : 51.00 %
# Trap (49) Loading Probability : 60.00 %
# Trap (50) Loading Probability : 61.00 %
# Trap (51) Loading Probability : 54.00 %
# Trap (52) Loading Probability : 60.00 %
# Trap (53) Loading Probability : 63.00 %
# Trap (54) Loading Probability : 57.00 %
# Trap (55) Loading Probability : 58.00 %
# Trap (56) Loading Probability : 59.00 %
# Trap (57) Loading Probability : 55.00 %
# Trap (58) Loading Probability : 51.00 %
# Trap (59) Loading Probability : 55.00 %
# Trap (60) Loading Probability : 68.00 %
# Trap (61) Loading Probability : 58.00 %
# Trap (62) Loading Probability : 61.00 %
# Trap (63) Loading Probability : 64.00 %
# Trap (64) Loading Probability : 61.00 %
# Trap (65) Loading Probability : 70.00 %
# Trap (66) Loading Probability : 61.00 %
# Trap (67) Loading Probability : 60.00 %
# Trap (68) Loading Probability : 58.00 %
# Trap (69) Loading Probability : 53.00 %
# Trap (70) Loading Probability : 59.00 %
# Trap (71) Loading Probability : 60.00 %
# Trap (72) Loading Probability : 60.00 %
# Trap (73) Loading Probability : 61.00 %
# Trap (74) Loading Probability : 54.00 %
# Trap (75) Loading Probability : 59.00 %
# Trap (76) Loading Probability : 53.00 %
# Trap (77) Loading Probability : 57.00 %
# Trap (78) Loading Probability : 62.00 %
# Trap (79) Loading Probability : 64.00 %
# Trap (80) Loading Probability : 49.00 %
# Trap (81) Loading Probability : 53.00 %
# Trap (82) Loading Probability : 59.00 %
# Trap (83) Loading Probability : 49.00 %
# Trap (84) Loading Probability : 51.00 %
# Trap (85) Loading Probability : 55.00 %
# Trap (86) Loading Probability : 56.00 %
# Trap (87) Loading Probability : 54.00 %
# Trap (88) Loading Probability : 60.00 %
# Trap (89) Loading Probability : 57.00 %
# Trap (90) Loading Probability : 59.00 %
# Trap (91) Loading Probability : 63.00 %
# Trap (92) Loading Probability : 57.00 %
# Trap (93) Loading Probability : 72.00 %
# Trap (94) Loading Probability : 54.00 %
# Trap (95) Loading Probability : 57.00 %
# Trap (96) Loading Probability : 53.00 %
# Trap (97) Loading Probability : 51.00 %
# Trap (98) Loading Probability : 50.00 %
# Trap (99) Loading Probability : 54.00 %
# Detected Loading Threshold: 70.00 photons
# Std dev of Loading Probabilities: 8.32 %
# Mean Loading Probability: 57.24 %
# Detection Fidelity: 0.87 %
# Mean Background Photon Count: 36.64 photons, Variance: 163.87 photons^2
# Mean Signal Photon Count: 146.02 photons, Variance: 829.26 photons^2
