# %% [markdown]
# ### SLM Client Testing

# %%
from pytweezer import communication as comm
import numpy as np

# %%
SLM = comm.SLMClient()

# %%
T = SLM.get_temperature()
print(T)
# Out:
# {'status': 'success', 'data': 1}

# %%
phasemask = np.ones((1200, 1920))
SLM.update_mask(phasemask)
# Out:
# {'status': 'success', 'msg': 'Mask updated successfully.'}
