# %%
from pytweezer.experiment import motmaster_client
from pytweezer.experiment.motmaster_interface import MotMasterInterface
from pytweezer.configuration.config import HOSTS, CONFIG
from sipyco.pc_rpc import Client
from pytweezer.experiment.motmaster_client import MotMasterClient

mm_host_addr = HOSTS["caf_mm_pc"]
mm_port = CONFIG["Servers"]["CaF MotMaster Server"]["port"]

# %%
exp: MotMasterInterface = motmaster_client(
            host="caf",
            timeout=5,
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 exp: MotMasterInterface = Client(
#       2             host="caf",
#       3             timeout=5,
#       4         )
#
# TypeError: Client.__init__() missing 1 required positional argument: 'port'

# %%
exp.set_motmaster_experiment("0. DDSFourSidebands5W_noDDS")

# %%
exp.start_motmaster_experiment()
