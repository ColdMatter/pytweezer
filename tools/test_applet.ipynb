# %%
from pytweezer.servers.device_client import get_device
from pytweezer.drivers.camera_base import Camera

cam: Camera = get_device("Rb HamCam")

# %%
cam.start_acquisition()
img = cam.acquire_n_frames(nframes=2, broadcast=True)

# %%
cam.close()
